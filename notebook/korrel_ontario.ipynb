# %% [markdown]
# 1. Import und Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# 2. Daten einlesen

# %%
file_path = "../data/cleaned_wlags_Number_of_fires_by_month.csv"
# CSV mit Semikolon-Trenner einlesen
df_fires = pd.read_csv(file_path, sep=",", header=0, encoding="ISO-8859-1")
print(df_fires.columns)
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires'], dtype='object')

# %%
file_path = "../data/cleaned_Ontario_monthly_mean.csv"
# CSV mit Semikolon-Trenner einlesen
df_weather = pd.read_csv(file_path, sep=",", header=0, encoding="ISO-8859-1")
print(df_fires.columns)
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires'], dtype='object')

# %% [markdown]
# 3. Datenbereinigung

# %%
# Monat numerisch machen
df_fires["Month"] = pd.to_datetime(df_fires["Month"], format="%B").dt.month

# Spalte time löschen
df_weather = df_weather.drop(columns=["time"])

#filter Ontario
df_fires_ontario = df_fires[df_fires["Jurisdiction"] == "Ontario"].copy()
df_fires_ontario["Jurisdiction"].unique()
# Out:
# array(['Ontario'], dtype=object)

# %% [markdown]
# 4. Merge data

# %%
print(df_fires_ontario.columns)
print(df_weather.columns)
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires'], dtype='object')
# Index(['temperature_2m_mean (Â°C)', 'temperature_2m_max (Â°C)',
#        'relative_humidity_2m_mean (%)', 'relative_humidity_2m_min (%)',
#        'precipitation_sum (mm)', 'precipitation_hours (h)',
#        'wind_speed_10m_mean (km/h)', 'wind_speed_10m_max (km/h)',
#        'wind_direction_10m_dominant (Â°)', 'et0_fao_evapotranspiration (mm)',
#        'Year', 'Month'],
#       dtype='object')

# %%
df_merged = pd.merge(
    df_fires_ontario,
    df_weather,
    on=["Year", "Month"],
    how="inner"
)

# %%
print(df_merged.columns)
print(df_merged.dtypes)
df_merged.head(10)
print(df_merged.shape)
duplicates = df_merged.duplicated(subset=["Jurisdiction", "Year", "Month"]).sum()
print("Doppelte Schlüssel:", duplicates)
df_merged.isna().sum()
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires',
#        'temperature_2m_mean (Â°C)', 'temperature_2m_max (Â°C)',
#        'relative_humidity_2m_mean (%)', 'relative_humidity_2m_min (%)',
#        'precipitation_sum (mm)', 'precipitation_hours (h)',
#        'wind_speed_10m_mean (km/h)', 'wind_speed_10m_max (km/h)',
#        'wind_direction_10m_dominant (Â°)', 'et0_fao_evapotranspiration (mm)'],
#       dtype='object')
# Jurisdiction                         object
# Month                                 int32
# Year                                  int64
# Number_fires                        float64
# temperature_2m_mean (Â°C)           float64
# temperature_2m_max (Â°C)            float64
# relative_humidity_2m_mean (%)       float64
# relative_humidity_2m_min (%)        float64
# precipitation_sum (mm)              float64
# precipitation_hours (h)             float64
# wind_speed_10m_mean (km/h)          float64
# wind_speed_10m_max (km/h)           float64
# wind_direction_10m_dominant (Â°)    float64
# et0_fao_evapotranspiration (mm)     float64
# dtype: object
# (397, 14)
# Doppelte Schlüssel: 0
# Jurisdiction                          0
# Month                                 0
# Year                                  0
# Number_fires                        103
# temperature_2m_mean (Â°C)             0
# temperature_2m_max (Â°C)              0
# relative_humidity_2m_mean (%)         0
# relative_humidity_2m_min (%)          0
# precipitation_sum (mm)                0
# precipitation_hours (h)               0
# wind_speed_10m_mean (km/h)            0
# wind_speed_10m_max (km/h)             0
# wind_direction_10m_dominant (Â°)      0
# et0_fao_evapotranspiration (mm)       0
# dtype: int64

# %% [markdown]
# 5. Korrelationsanalyse

# %%
corr_cols = [
    "Number_fires",
    "temperature_2m_mean (Â°C)",
    "temperature_2m_max (Â°C)",
    "relative_humidity_2m_mean (%)",
    "relative_humidity_2m_min (%)",
    "precipitation_sum (mm)",
    "precipitation_hours (h)",
    "wind_speed_10m_mean (km/h)",
    "wind_speed_10m_max (km/h)",
    "wind_direction_10m_dominant (Â°)",
    "et0_fao_evapotranspiration (mm)"
]

df_corr = df_merged[corr_cols].dropna()

# %%
pearson_corr = df_corr.corr(method="pearson")
print(pearson_corr)
# Out:
#                                   Number_fires  temperature_2m_mean (Â°C)  \
# Number_fires                          1.000000                   0.522005
# temperature_2m_mean (Â°C)             0.522005                   1.000000
# temperature_2m_max (Â°C)              0.544263                   0.996380
# relative_humidity_2m_mean (%)        -0.426075                  -0.175796
# relative_humidity_2m_min (%)         -0.521868                  -0.489910
# precipitation_sum (mm)                0.184132                   0.664880
# precipitation_hours (h)              -0.214154                   0.189257
# wind_speed_10m_mean (km/h)           -0.426609                  -0.398365
# wind_speed_10m_max (km/h)            -0.312435                  -0.228847
# wind_direction_10m_dominant (Â°)      0.196502                   0.019258
# et0_fao_evapotranspiration (mm)       0.634317                   0.848673
#
#                                   temperature_2m_max (Â°C)  \
# Number_fires                                      0.544263
# temperature_2m_mean (Â°C)                         0.996380
# temperature_2m_max (Â°C)                          1.000000
# relative_humidity_2m_mean (%)                    -0.248045
# relative_humidity_2m_min (%)                     -0.553618
# precipitation_sum (mm)                            0.633648
# precipitation_hours (h)                           0.137395
# wind_speed_10m_mean (km/h)                       -0.423007
# wind_speed_10m_max (km/h)                        -0.247396
# wind_direction_10m_dominant (Â°)                  0.014829
# et0_fao_evapotranspiration (mm)                   0.885662
#
#                                   relative_humidity_2m_mean (%)  \
# Number_fires                                          -0.426075
# temperature_2m_mean (Â°C)                             -0.175796
# temperature_2m_max (Â°C)                              -0.248045
# relative_humidity_2m_mean (%)                          1.000000
# relative_humidity_2m_min (%)                           0.918188
# precipitation_sum (mm)                                 0.310645
# precipitation_hours (h)                                0.601261
# wind_speed_10m_mean (km/h)                             0.288468
# wind_speed_10m_max (km/h)                              0.195902
# wind_direction_10m_dominant (Â°)                      -0.026834
# et0_fao_evapotranspiration (mm)                       -0.612609
#
#                                   relative_humidity_2m_min (%)  \
# Number_fires                                         -0.521868
# temperature_2m_mean (Â°C)                            -0.489910
# temperature_2m_max (Â°C)                             -0.553618
# relative_humidity_2m_mean (%)                         0.918188
# relative_humidity_2m_min (%)                          1.000000
# precipitation_sum (mm)                                0.017661
# precipitation_hours (h)                               0.423962
# wind_speed_10m_mean (km/h)                            0.391381
# wind_speed_10m_max (km/h)                             0.238438
# wind_direction_10m_dominant (Â°)                     -0.007886
# et0_fao_evapotranspiration (mm)                      -0.816947
#
#                                   precipitation_sum (mm)  \
# Number_fires                                    0.184132
# temperature_2m_mean (Â°C)                       0.664880
# temperature_2m_max (Â°C)                        0.633648
# relative_humidity_2m_mean (%)                   0.310645
# relative_humidity_2m_min (%)                    0.017661
# precipitation_sum (mm)                          1.000000
# precipitation_hours (h)                         0.699576
# wind_speed_10m_mean (km/h)                     -0.015536
# wind_speed_10m_max (km/h)                       0.142491
# wind_direction_10m_dominant (Â°)                0.027920
# et0_fao_evapotranspiration (mm)                 0.367966
#
#                                   precipitation_hours (h)  \
# Number_fires                                    -0.214154
# temperature_2m_mean (Â°C)                        0.189257
# temperature_2m_max (Â°C)                         0.137395
# relative_humidity_2m_mean (%)                    0.601261
# relative_humidity_2m_min (%)                     0.423962
# precipitation_sum (mm)                           0.699576
# precipitation_hours (h)                          1.000000
# wind_speed_10m_mean (km/h)                       0.348997
# wind_speed_10m_max (km/h)                        0.421494
# wind_direction_10m_dominant (Â°)                -0.013538
# et0_fao_evapotranspiration (mm)                 -0.152905
#
#                                   wind_speed_10m_mean (km/h)  \
# Number_fires                                       -0.426609
# temperature_2m_mean (Â°C)                          -0.398365
# temperature_2m_max (Â°C)                           -0.423007
# relative_humidity_2m_mean (%)                       0.288468
# relative_humidity_2m_min (%)                        0.391381
# precipitation_sum (mm)                             -0.015536
# precipitation_hours (h)                             0.348997
# wind_speed_10m_mean (km/h)                          1.000000
# wind_speed_10m_max (km/h)                           0.943243
# wind_direction_10m_dominant (Â°)                    0.135696
# et0_fao_evapotranspiration (mm)                    -0.561468
#
#                                   wind_speed_10m_max (km/h)  \
# Number_fires                                      -0.312435
# temperature_2m_mean (Â°C)                         -0.228847
# temperature_2m_max (Â°C)                          -0.247396
# relative_humidity_2m_mean (%)                      0.195902
# relative_humidity_2m_min (%)                       0.238438
# precipitation_sum (mm)                             0.142491
# precipitation_hours (h)                            0.421494
# wind_speed_10m_mean (km/h)                         0.943243
# wind_speed_10m_max (km/h)                          1.000000
# wind_direction_10m_dominant (Â°)                   0.196710
# et0_fao_evapotranspiration (mm)                   -0.376981
#
#                                   wind_direction_10m_dominant (Â°)  \
# Number_fires                                              0.196502
# temperature_2m_mean (Â°C)                                 0.019258
# temperature_2m_max (Â°C)                                  0.014829
# relative_humidity_2m_mean (%)                            -0.026834
# relative_humidity_2m_min (%)                             -0.007886
# precipitation_sum (mm)                                    0.027920
# precipitation_hours (h)                                  -0.013538
# wind_speed_10m_mean (km/h)                                0.135696
# wind_speed_10m_max (km/h)                                 0.196710
# wind_direction_10m_dominant (Â°)                          1.000000
# et0_fao_evapotranspiration (mm)                           0.014805
#
#                                   et0_fao_evapotranspiration (mm)
# Number_fires                                             0.634317
# temperature_2m_mean (Â°C)                                0.848673
# temperature_2m_max (Â°C)                                 0.885662
# relative_humidity_2m_mean (%)                           -0.612609
# relative_humidity_2m_min (%)                            -0.816947
# precipitation_sum (mm)                                   0.367966
# precipitation_hours (h)                                 -0.152905
# wind_speed_10m_mean (km/h)                              -0.561468
# wind_speed_10m_max (km/h)                               -0.376981
# wind_direction_10m_dominant (Â°)                         0.014805
# et0_fao_evapotranspiration (mm)                          1.000000

# %%
spearman_corr = df_corr.corr(method="spearman")
print(spearman_corr)
# Out:
#                                   Number_fires  temperature_2m_mean (Â°C)  \
# Number_fires                          1.000000                   0.709059
# temperature_2m_mean (Â°C)             0.709059                   1.000000
# temperature_2m_max (Â°C)              0.737449                   0.994665
# relative_humidity_2m_mean (%)        -0.501937                  -0.172475
# relative_humidity_2m_min (%)         -0.690828                  -0.484156
# precipitation_sum (mm)                0.262742                   0.649903
# precipitation_hours (h)              -0.207517                   0.137865
# wind_speed_10m_mean (km/h)           -0.499760                  -0.516109
# wind_speed_10m_max (km/h)            -0.353686                  -0.333329
# wind_direction_10m_dominant (Â°)      0.088992                   0.105893
# et0_fao_evapotranspiration (mm)       0.817446                   0.873562
#
#                                   temperature_2m_max (Â°C)  \
# Number_fires                                      0.737449
# temperature_2m_mean (Â°C)                         0.994665
# temperature_2m_max (Â°C)                          1.000000
# relative_humidity_2m_mean (%)                    -0.246469
# relative_humidity_2m_min (%)                     -0.547998
# precipitation_sum (mm)                            0.612884
# precipitation_hours (h)                           0.084541
# wind_speed_10m_mean (km/h)                       -0.525833
# wind_speed_10m_max (km/h)                        -0.339739
# wind_direction_10m_dominant (Â°)                  0.098560
# et0_fao_evapotranspiration (mm)                   0.909505
#
#                                   relative_humidity_2m_mean (%)  \
# Number_fires                                          -0.501937
# temperature_2m_mean (Â°C)                             -0.172475
# temperature_2m_max (Â°C)                              -0.246469
# relative_humidity_2m_mean (%)                          1.000000
# relative_humidity_2m_min (%)                           0.913966
# precipitation_sum (mm)                                 0.329917
# precipitation_hours (h)                                0.618640
# wind_speed_10m_mean (km/h)                             0.301315
# wind_speed_10m_max (km/h)                              0.204153
# wind_direction_10m_dominant (Â°)                      -0.028565
# et0_fao_evapotranspiration (mm)                       -0.580415
#
#                                   relative_humidity_2m_min (%)  \
# Number_fires                                         -0.690828
# temperature_2m_mean (Â°C)                            -0.484156
# temperature_2m_max (Â°C)                             -0.547998
# relative_humidity_2m_mean (%)                         0.913966
# relative_humidity_2m_min (%)                          1.000000
# precipitation_sum (mm)                                0.036845
# precipitation_hours (h)                               0.438542
# wind_speed_10m_mean (km/h)                            0.420259
# wind_speed_10m_max (km/h)                             0.254876
# wind_direction_10m_dominant (Â°)                     -0.029151
# et0_fao_evapotranspiration (mm)                      -0.813937
#
#                                   precipitation_sum (mm)  \
# Number_fires                                    0.262742
# temperature_2m_mean (Â°C)                       0.649903
# temperature_2m_max (Â°C)                        0.612884
# relative_humidity_2m_mean (%)                   0.329917
# relative_humidity_2m_min (%)                    0.036845
# precipitation_sum (mm)                          1.000000
# precipitation_hours (h)                         0.691226
# wind_speed_10m_mean (km/h)                     -0.058283
# wind_speed_10m_max (km/h)                       0.095345
# wind_direction_10m_dominant (Â°)                0.043833
# et0_fao_evapotranspiration (mm)                 0.379515
#
#                                   precipitation_hours (h)  \
# Number_fires                                    -0.207517
# temperature_2m_mean (Â°C)                        0.137865
# temperature_2m_max (Â°C)                         0.084541
# relative_humidity_2m_mean (%)                    0.618640
# relative_humidity_2m_min (%)                     0.438542
# precipitation_sum (mm)                           0.691226
# precipitation_hours (h)                          1.000000
# wind_speed_10m_mean (km/h)                       0.301034
# wind_speed_10m_max (km/h)                        0.367660
# wind_direction_10m_dominant (Â°)                -0.017100
# et0_fao_evapotranspiration (mm)                 -0.145984
#
#                                   wind_speed_10m_mean (km/h)  \
# Number_fires                                       -0.499760
# temperature_2m_mean (Â°C)                          -0.516109
# temperature_2m_max (Â°C)                           -0.525833
# relative_humidity_2m_mean (%)                       0.301315
# relative_humidity_2m_min (%)                        0.420259
# precipitation_sum (mm)                             -0.058283
# precipitation_hours (h)                             0.301034
# wind_speed_10m_mean (km/h)                          1.000000
# wind_speed_10m_max (km/h)                           0.934833
# wind_direction_10m_dominant (Â°)                    0.097226
# et0_fao_evapotranspiration (mm)                    -0.558013
#
#                                   wind_speed_10m_max (km/h)  \
# Number_fires                                      -0.353686
# temperature_2m_mean (Â°C)                         -0.333329
# temperature_2m_max (Â°C)                          -0.339739
# relative_humidity_2m_mean (%)                      0.204153
# relative_humidity_2m_min (%)                       0.254876
# precipitation_sum (mm)                             0.095345
# precipitation_hours (h)                            0.367660
# wind_speed_10m_mean (km/h)                         0.934833
# wind_speed_10m_max (km/h)                          1.000000
# wind_direction_10m_dominant (Â°)                   0.163700
# et0_fao_evapotranspiration (mm)                   -0.364955
#
#                                   wind_direction_10m_dominant (Â°)  \
# Number_fires                                              0.088992
# temperature_2m_mean (Â°C)                                 0.105893
# temperature_2m_max (Â°C)                                  0.098560
# relative_humidity_2m_mean (%)                            -0.028565
# relative_humidity_2m_min (%)                             -0.029151
# precipitation_sum (mm)                                    0.043833
# precipitation_hours (h)                                  -0.017100
# wind_speed_10m_mean (km/h)                                0.097226
# wind_speed_10m_max (km/h)                                 0.163700
# wind_direction_10m_dominant (Â°)                          1.000000
# et0_fao_evapotranspiration (mm)                           0.036904
#
#                                   et0_fao_evapotranspiration (mm)
# Number_fires                                             0.817446
# temperature_2m_mean (Â°C)                                0.873562
# temperature_2m_max (Â°C)                                 0.909505
# relative_humidity_2m_mean (%)                           -0.580415
# relative_humidity_2m_min (%)                            -0.813937
# precipitation_sum (mm)                                   0.379515
# precipitation_hours (h)                                 -0.145984
# wind_speed_10m_mean (km/h)                              -0.558013
# wind_speed_10m_max (km/h)                               -0.364955
# wind_direction_10m_dominant (Â°)                         0.036904
# et0_fao_evapotranspiration (mm)                          1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    pearson_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Pearson Correlation – British Columbia")
plt.tight_layout()
plt.show()

# %%
#Spearman heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    spearman_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Spearman Correlation – British Columbia")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(
    df_corr,
    kind="scatter",
    diag_kind="hist"
)
plt.suptitle("Scatterplots – Weather vs. Fires (British Columbia)", y=1.02)
plt.show()
