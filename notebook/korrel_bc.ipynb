# %% [markdown]
# 1. Import und Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# 2. Daten einlesen

# %%
file_path = "../data/cleaned_wlags_Number_of_fires_by_month.csv"
# CSV mit Semikolon-Trenner einlesen
df_fires = pd.read_csv(file_path, sep=",", header=0, encoding="ISO-8859-1")
print(df_fires.columns)
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires'], dtype='object')

# %%
file_path = "../data/cleaned_British_Columbia_monthly_mean.csv"
# CSV mit Semikolon-Trenner einlesen
df_weather = pd.read_csv(file_path, sep=",", header=0, encoding="ISO-8859-1")
print(df_fires.columns)
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires'], dtype='object')

# %% [markdown]
# 3. Datenbereinigung

# %%
# Monat numerisch machen
df_fires["Month"] = pd.to_datetime(df_fires["Month"], format="%B").dt.month

# sicherstellen, dass 'time' ein Datetime ist
df_weather["time"] = pd.to_datetime(df_weather["time"])

# Jahr und Monat extrahieren
df_weather["Year"] = df_weather["time"].dt.year
df_weather["Month"] = df_weather["time"].dt.month
df_weather = df_weather.drop(columns=["time"])

#filter british columbia
df_fires_bc = df_fires[df_fires["Jurisdiction"] == "British Columbia"].copy()
df_fires_bc["Jurisdiction"].unique()
# Out:
# array(['British Columbia'], dtype=object)

# %% [markdown]
# 4. Merge data

# %%
print(df_fires_bc.columns)
print(df_weather.columns)
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires'], dtype='object')
# Index(['temperature_2m_mean (Â°C)', 'temperature_2m_max (Â°C)',
#        'relative_humidity_2m_mean (%)', 'relative_humidity_2m_min (%)',
#        'precipitation_sum (mm)', 'precipitation_hours (h)',
#        'wind_speed_10m_mean (km/h)', 'wind_speed_10m_max (km/h)',
#        'wind_direction_10m_dominant (Â°)', 'et0_fao_evapotranspiration (mm)',
#        'Year', 'Month'],
#       dtype='object')

# %%
df_merged = pd.merge(
    df_fires_bc,
    df_weather,
    on=["Year", "Month"],
    how="inner"
)

# %%
print(df_merged.columns)
print(df_merged.dtypes)
df_merged.head(10)
print(df_merged.shape)
duplicates = df_merged.duplicated(subset=["Jurisdiction", "Year", "Month"]).sum()
print("Doppelte Schlüssel:", duplicates)
df_merged.isna().sum()
# Out:
# Index(['Jurisdiction', 'Month', 'Year', 'Number_fires',
#        'temperature_2m_mean (Â°C)', 'temperature_2m_max (Â°C)',
#        'relative_humidity_2m_mean (%)', 'relative_humidity_2m_min (%)',
#        'precipitation_sum (mm)', 'precipitation_hours (h)',
#        'wind_speed_10m_mean (km/h)', 'wind_speed_10m_max (km/h)',
#        'wind_direction_10m_dominant (Â°)', 'et0_fao_evapotranspiration (mm)'],
#       dtype='object')
# Jurisdiction                         object
# Month                                 int32
# Year                                  int64
# Number_fires                        float64
# temperature_2m_mean (Â°C)           float64
# temperature_2m_max (Â°C)            float64
# relative_humidity_2m_mean (%)       float64
# relative_humidity_2m_min (%)        float64
# precipitation_sum (mm)              float64
# precipitation_hours (h)             float64
# wind_speed_10m_mean (km/h)          float64
# wind_speed_10m_max (km/h)           float64
# wind_direction_10m_dominant (Â°)    float64
# et0_fao_evapotranspiration (mm)     float64
# dtype: object
# (397, 14)
# Doppelte Schlüssel: 0
# Jurisdiction                         0
# Month                                0
# Year                                 0
# Number_fires                        29
# temperature_2m_mean (Â°C)            0
# temperature_2m_max (Â°C)             0
# relative_humidity_2m_mean (%)        0
# relative_humidity_2m_min (%)         0
# precipitation_sum (mm)               0
# precipitation_hours (h)              0
# wind_speed_10m_mean (km/h)           0
# wind_speed_10m_max (km/h)            0
# wind_direction_10m_dominant (Â°)     0
# et0_fao_evapotranspiration (mm)      0
# dtype: int64

# %% [markdown]
# 5. Korrelationsanalyse

# %%
corr_cols = [
    "Number_fires",
    "temperature_2m_mean (Â°C)",
    "temperature_2m_max (Â°C)",
    "relative_humidity_2m_mean (%)",
    "relative_humidity_2m_min (%)",
    "precipitation_sum (mm)",
    "precipitation_hours (h)",
    "wind_speed_10m_mean (km/h)",
    "wind_speed_10m_max (km/h)",
    "wind_direction_10m_dominant (Â°)",
    "et0_fao_evapotranspiration (mm)"
]

df_corr = df_merged[corr_cols].dropna()

# %%
pearson_corr = df_corr.corr(method="pearson")
print(pearson_corr)
# Out:
#                                   Number_fires  temperature_2m_mean (Â°C)  \
# Number_fires                          1.000000                   0.641698
# temperature_2m_mean (Â°C)             0.641698                   1.000000
# temperature_2m_max (Â°C)              0.645687                   0.996984
# relative_humidity_2m_mean (%)        -0.601578                  -0.778067
# relative_humidity_2m_min (%)         -0.564790                  -0.845240
# precipitation_sum (mm)               -0.147455                   0.080547
# precipitation_hours (h)              -0.426041                  -0.385961
# wind_speed_10m_mean (km/h)           -0.400625                  -0.403046
# wind_speed_10m_max (km/h)            -0.151574                   0.054681
# wind_direction_10m_dominant (Â°)      0.382765                   0.547599
# et0_fao_evapotranspiration (mm)       0.649688                   0.923596
#
#                                   temperature_2m_max (Â°C)  \
# Number_fires                                      0.645687
# temperature_2m_mean (Â°C)                         0.996984
# temperature_2m_max (Â°C)                          1.000000
# relative_humidity_2m_mean (%)                    -0.811920
# relative_humidity_2m_min (%)                     -0.877470
# precipitation_sum (mm)                            0.042505
# precipitation_hours (h)                          -0.416762
# wind_speed_10m_mean (km/h)                       -0.413210
# wind_speed_10m_max (km/h)                         0.061996
# wind_direction_10m_dominant (Â°)                  0.560949
# et0_fao_evapotranspiration (mm)                   0.938361
#
#                                   relative_humidity_2m_mean (%)  \
# Number_fires                                          -0.601578
# temperature_2m_mean (Â°C)                             -0.778067
# temperature_2m_max (Â°C)                              -0.811920
# relative_humidity_2m_mean (%)                          1.000000
# relative_humidity_2m_min (%)                           0.965480
# precipitation_sum (mm)                                 0.269074
# precipitation_hours (h)                                0.565657
# wind_speed_10m_mean (km/h)                             0.289910
# wind_speed_10m_max (km/h)                             -0.193714
# wind_direction_10m_dominant (Â°)                      -0.607163
# et0_fao_evapotranspiration (mm)                       -0.894838
#
#                                   relative_humidity_2m_min (%)  \
# Number_fires                                         -0.564790
# temperature_2m_mean (Â°C)                            -0.845240
# temperature_2m_max (Â°C)                             -0.877470
# relative_humidity_2m_mean (%)                         0.965480
# relative_humidity_2m_min (%)                          1.000000
# precipitation_sum (mm)                                0.182876
# precipitation_hours (h)                               0.521648
# wind_speed_10m_mean (km/h)                            0.328147
# wind_speed_10m_max (km/h)                            -0.193986
# wind_direction_10m_dominant (Â°)                     -0.586551
# et0_fao_evapotranspiration (mm)                      -0.905224
#
#                                   precipitation_sum (mm)  \
# Number_fires                                   -0.147455
# temperature_2m_mean (Â°C)                       0.080547
# temperature_2m_max (Â°C)                        0.042505
# relative_humidity_2m_mean (%)                   0.269074
# relative_humidity_2m_min (%)                    0.182876
# precipitation_sum (mm)                          1.000000
# precipitation_hours (h)                         0.807825
# wind_speed_10m_mean (km/h)                      0.030373
# wind_speed_10m_max (km/h)                       0.036889
# wind_direction_10m_dominant (Â°)               -0.062979
# et0_fao_evapotranspiration (mm)                 0.005794
#
#                                   precipitation_hours (h)  \
# Number_fires                                    -0.426041
# temperature_2m_mean (Â°C)                       -0.385961
# temperature_2m_max (Â°C)                        -0.416762
# relative_humidity_2m_mean (%)                    0.565657
# relative_humidity_2m_min (%)                     0.521648
# precipitation_sum (mm)                           0.807825
# precipitation_hours (h)                          1.000000
# wind_speed_10m_mean (km/h)                       0.246540
# wind_speed_10m_max (km/h)                        0.066891
# wind_direction_10m_dominant (Â°)                -0.331623
# et0_fao_evapotranspiration (mm)                 -0.401690
#
#                                   wind_speed_10m_mean (km/h)  \
# Number_fires                                       -0.400625
# temperature_2m_mean (Â°C)                          -0.403046
# temperature_2m_max (Â°C)                           -0.413210
# relative_humidity_2m_mean (%)                       0.289910
# relative_humidity_2m_min (%)                        0.328147
# precipitation_sum (mm)                              0.030373
# precipitation_hours (h)                             0.246540
# wind_speed_10m_mean (km/h)                          1.000000
# wind_speed_10m_max (km/h)                           0.816297
# wind_direction_10m_dominant (Â°)                   -0.201389
# et0_fao_evapotranspiration (mm)                    -0.458581
#
#                                   wind_speed_10m_max (km/h)  \
# Number_fires                                      -0.151574
# temperature_2m_mean (Â°C)                          0.054681
# temperature_2m_max (Â°C)                           0.061996
# relative_humidity_2m_mean (%)                     -0.193714
# relative_humidity_2m_min (%)                      -0.193986
# precipitation_sum (mm)                             0.036889
# precipitation_hours (h)                            0.066891
# wind_speed_10m_mean (km/h)                         0.816297
# wind_speed_10m_max (km/h)                          1.000000
# wind_direction_10m_dominant (Â°)                   0.110930
# et0_fao_evapotranspiration (mm)                    0.030432
#
#                                   wind_direction_10m_dominant (Â°)  \
# Number_fires                                              0.382765
# temperature_2m_mean (Â°C)                                 0.547599
# temperature_2m_max (Â°C)                                  0.560949
# relative_humidity_2m_mean (%)                            -0.607163
# relative_humidity_2m_min (%)                             -0.586551
# precipitation_sum (mm)                                   -0.062979
# precipitation_hours (h)                                  -0.331623
# wind_speed_10m_mean (km/h)                               -0.201389
# wind_speed_10m_max (km/h)                                 0.110930
# wind_direction_10m_dominant (Â°)                          1.000000
# et0_fao_evapotranspiration (mm)                           0.599928
#
#                                   et0_fao_evapotranspiration (mm)
# Number_fires                                             0.649688
# temperature_2m_mean (Â°C)                                0.923596
# temperature_2m_max (Â°C)                                 0.938361
# relative_humidity_2m_mean (%)                           -0.894838
# relative_humidity_2m_min (%)                            -0.905224
# precipitation_sum (mm)                                   0.005794
# precipitation_hours (h)                                 -0.401690
# wind_speed_10m_mean (km/h)                              -0.458581
# wind_speed_10m_max (km/h)                                0.030432
# wind_direction_10m_dominant (Â°)                         0.599928
# et0_fao_evapotranspiration (mm)                          1.000000

# %%
spearman_corr = df_corr.corr(method="spearman")
print(spearman_corr)
# Out:
#                                   Number_fires  temperature_2m_mean (Â°C)  \
# Number_fires                          1.000000                   0.917959
# temperature_2m_mean (Â°C)             0.917959                   1.000000
# temperature_2m_max (Â°C)              0.929927                   0.996408
# relative_humidity_2m_mean (%)        -0.865109                  -0.784080
# relative_humidity_2m_min (%)         -0.894114                  -0.844042
# precipitation_sum (mm)               -0.104771                   0.044543
# precipitation_hours (h)              -0.507238                  -0.409497
# wind_speed_10m_mean (km/h)           -0.422116                  -0.425969
# wind_speed_10m_max (km/h)             0.015928                   0.017031
# wind_direction_10m_dominant (Â°)      0.553481                   0.569614
# et0_fao_evapotranspiration (mm)       0.916007                   0.929873
#
#                                   temperature_2m_max (Â°C)  \
# Number_fires                                      0.929927
# temperature_2m_mean (Â°C)                         0.996408
# temperature_2m_max (Â°C)                          1.000000
# relative_humidity_2m_mean (%)                    -0.815653
# relative_humidity_2m_min (%)                     -0.872661
# precipitation_sum (mm)                            0.005624
# precipitation_hours (h)                          -0.438709
# wind_speed_10m_mean (km/h)                       -0.431351
# wind_speed_10m_max (km/h)                         0.028167
# wind_direction_10m_dominant (Â°)                  0.577446
# et0_fao_evapotranspiration (mm)                   0.946836
#
#                                   relative_humidity_2m_mean (%)  \
# Number_fires                                          -0.865109
# temperature_2m_mean (Â°C)                             -0.784080
# temperature_2m_max (Â°C)                              -0.815653
# relative_humidity_2m_mean (%)                          1.000000
# relative_humidity_2m_min (%)                           0.984205
# precipitation_sum (mm)                                 0.275942
# precipitation_hours (h)                                0.568681
# wind_speed_10m_mean (km/h)                             0.298242
# wind_speed_10m_max (km/h)                             -0.170084
# wind_direction_10m_dominant (Â°)                      -0.601771
# et0_fao_evapotranspiration (mm)                       -0.904643
#
#                                   relative_humidity_2m_min (%)  \
# Number_fires                                         -0.894114
# temperature_2m_mean (Â°C)                            -0.844042
# temperature_2m_max (Â°C)                             -0.872661
# relative_humidity_2m_mean (%)                         0.984205
# relative_humidity_2m_min (%)                          1.000000
# precipitation_sum (mm)                                0.234455
# precipitation_hours (h)                               0.555494
# wind_speed_10m_mean (km/h)                            0.332953
# wind_speed_10m_max (km/h)                            -0.155760
# wind_direction_10m_dominant (Â°)                     -0.593347
# et0_fao_evapotranspiration (mm)                      -0.931100
#
#                                   precipitation_sum (mm)  \
# Number_fires                                   -0.104771
# temperature_2m_mean (Â°C)                       0.044543
# temperature_2m_max (Â°C)                        0.005624
# relative_humidity_2m_mean (%)                   0.275942
# relative_humidity_2m_min (%)                    0.234455
# precipitation_sum (mm)                          1.000000
# precipitation_hours (h)                         0.824900
# wind_speed_10m_mean (km/h)                      0.066003
# wind_speed_10m_max (km/h)                       0.055232
# wind_direction_10m_dominant (Â°)               -0.078729
# et0_fao_evapotranspiration (mm)                -0.051000
#
#                                   precipitation_hours (h)  \
# Number_fires                                    -0.507238
# temperature_2m_mean (Â°C)                       -0.409497
# temperature_2m_max (Â°C)                        -0.438709
# relative_humidity_2m_mean (%)                    0.568681
# relative_humidity_2m_min (%)                     0.555494
# precipitation_sum (mm)                           0.824900
# precipitation_hours (h)                          1.000000
# wind_speed_10m_mean (km/h)                       0.275347
# wind_speed_10m_max (km/h)                        0.101945
# wind_direction_10m_dominant (Â°)                -0.330163
# et0_fao_evapotranspiration (mm)                 -0.438406
#
#                                   wind_speed_10m_mean (km/h)  \
# Number_fires                                       -0.422116
# temperature_2m_mean (Â°C)                          -0.425969
# temperature_2m_max (Â°C)                           -0.431351
# relative_humidity_2m_mean (%)                       0.298242
# relative_humidity_2m_min (%)                        0.332953
# precipitation_sum (mm)                              0.066003
# precipitation_hours (h)                             0.275347
# wind_speed_10m_mean (km/h)                          1.000000
# wind_speed_10m_max (km/h)                           0.815014
# wind_direction_10m_dominant (Â°)                   -0.221239
# et0_fao_evapotranspiration (mm)                    -0.437811
#
#                                   wind_speed_10m_max (km/h)  \
# Number_fires                                       0.015928
# temperature_2m_mean (Â°C)                          0.017031
# temperature_2m_max (Â°C)                           0.028167
# relative_humidity_2m_mean (%)                     -0.170084
# relative_humidity_2m_min (%)                      -0.155760
# precipitation_sum (mm)                             0.055232
# precipitation_hours (h)                            0.101945
# wind_speed_10m_mean (km/h)                         0.815014
# wind_speed_10m_max (km/h)                          1.000000
# wind_direction_10m_dominant (Â°)                   0.079084
# et0_fao_evapotranspiration (mm)                    0.048311
#
#                                   wind_direction_10m_dominant (Â°)  \
# Number_fires                                              0.553481
# temperature_2m_mean (Â°C)                                 0.569614
# temperature_2m_max (Â°C)                                  0.577446
# relative_humidity_2m_mean (%)                            -0.601771
# relative_humidity_2m_min (%)                             -0.593347
# precipitation_sum (mm)                                   -0.078729
# precipitation_hours (h)                                  -0.330163
# wind_speed_10m_mean (km/h)                               -0.221239
# wind_speed_10m_max (km/h)                                 0.079084
# wind_direction_10m_dominant (Â°)                          1.000000
# et0_fao_evapotranspiration (mm)                           0.594665
#
#                                   et0_fao_evapotranspiration (mm)
# Number_fires                                             0.916007
# temperature_2m_mean (Â°C)                                0.929873
# temperature_2m_max (Â°C)                                 0.946836
# relative_humidity_2m_mean (%)                           -0.904643
# relative_humidity_2m_min (%)                            -0.931100
# precipitation_sum (mm)                                  -0.051000
# precipitation_hours (h)                                 -0.438406
# wind_speed_10m_mean (km/h)                              -0.437811
# wind_speed_10m_max (km/h)                                0.048311
# wind_direction_10m_dominant (Â°)                         0.594665
# et0_fao_evapotranspiration (mm)                          1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    pearson_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Pearson Correlation – British Columbia")
plt.tight_layout()
plt.show()

# %%
#Spearman heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    spearman_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Spearman Correlation – British Columbia")
plt.tight_layout()
plt.show()

# %%
sns.pairplot(
    df_corr,
    kind="scatter",
    diag_kind="hist"
)
plt.suptitle("Scatterplots – Weather vs. Fires (British Columbia)", y=1.02)
plt.show()
