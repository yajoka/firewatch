# %% [markdown]
# ### Wetter Daten laden (Von 1990 bis 2023)

# %% [markdown]
# ### British Columbia (BC)

# %%
#Cariboo Region (Williams Lake Area)
#→ 52.15, -122.15

import pandas as pd

pfad = "../data/import weather data/import data/British Columbia/open-meteo-52.55N122.18W978m-2.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
British_Columbia_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

British_Columbia_1
# Out:
#        latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      52.54833  -122.17876  1990-01-01                      -4.5
# 1      52.54833  -122.17876  1990-01-02                     -12.9
# 2      52.54833  -122.17876  1990-01-03                      -7.0
# 3      52.54833  -122.17876  1990-01-04                      -6.8
# 4      52.54833  -122.17876  1990-01-05                      -3.4
# ...         ...         ...         ...                       ...
# 12049  52.54833  -122.17876  2022-12-28                      -1.6
# 12050  52.54833  -122.17876  2022-12-29                      -5.7
# 12051  52.54833  -122.17876  2022-12-30                      -3.5
# 12052  52.54833  -122.17876  2022-12-31                      -3.6
# 12053  52.54833  -122.17876  2023-01-01                      -6.1
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -0.7                             88
# 1                         -6.4                             80
# 2                         -4.6                             85
# 3                         -4.0                             88
# 4                          1.2                             83
# ...                        ...                            ...
# 12049                      0.3                             93
# 12050                     -2.5                             89
# 12051                     -0.7                             87
# 12052                     -2.2                             91
# 12053                     -2.7                             91
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.6                              135
# 1                         1.6                              121
# 2                         9.5                              133
# 3                         5.1                              129
# 4                         2.4                              136
# ...                       ...                              ...
# 12049                     1.5                              307
# 12050                     0.0                              137
# 12051                     2.0                              125
# 12052                     4.1                              128
# 12053                     0.0                              154
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.22                      2.0
# 1                                 0.13                      5.0
# 2                                 0.17                     24.0
# 3                                 0.19                     11.0
# 4                                 0.38                      7.0
# ...                                ...                      ...
# 12049                             0.21                      8.0
# 12050                             0.21                      0.0
# 12051                             0.23                     11.0
# 12052                             0.16                      7.0
# 12053                             0.19                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           16.5                         9.4
# 1                           11.5                         6.8
# 2                           13.5                        12.2
# 3                           15.0                        10.3
# 4                           23.6                        16.3
# ...                          ...                         ...
# 12049                       10.8                         5.9
# 12050                       17.4                         9.7
# 12051                       16.0                        13.8
# 12052                       12.1                         7.8
# 12053                        7.8                         5.0
#
#        relative_humidity_2m_min (%)
# 0                                74
# 1                                69
# 2                                79
# 3                                80
# 4                                67
# ...                             ...
# 12049                            73
# 12050                            72
# 12051                            79
# 12052                            86
# 12053                            78
#
# [12054 rows x 13 columns]

# %%
#Okanagan – feueranfälligste Region in BC
#→ 49.80, -119.60

pfad = "../data/import weather data/import data/British Columbia/open-meteo-49.81N119.69W339m-2.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
British_Columbia_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

British_Columbia_2
# Out:
#         latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      49.806675  -119.6875  1990-01-01                       0.2
# 1      49.806675  -119.6875  1990-01-02                      -0.2
# 2      49.806675  -119.6875  1990-01-03                      -1.8
# 3      49.806675  -119.6875  1990-01-04                      -0.5
# 4      49.806675  -119.6875  1990-01-05                       1.8
# ...          ...        ...         ...                       ...
# 12049  49.806675  -119.6875  2022-12-28                       3.5
# 12050  49.806675  -119.6875  2022-12-29                      -2.1
# 12051  49.806675  -119.6875  2022-12-30                       0.5
# 12052  49.806675  -119.6875  2022-12-31                       0.3
# 12053  49.806675  -119.6875  2023-01-01                       1.7
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          3.0                             94
# 1                          2.3                             78
# 2                          1.1                             84
# 3                          3.6                             87
# 4                          4.0                             87
# ...                        ...                            ...
# 12049                      5.1                             88
# 12050                      3.4                             86
# 12051                      3.3                             87
# 12052                      4.1                             88
# 12053                      4.1                             82
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.3                              170
# 1                         0.8                              244
# 2                         0.9                              188
# 3                         4.0                              166
# 4                         1.3                              188
# ...                       ...                              ...
# 12049                     2.6                              213
# 12050                     0.0                              288
# 12051                     4.6                              314
# 12052                     0.8                              277
# 12053                     2.0                              217
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.34                      3.0
# 1                                 0.41                      5.0
# 2                                 0.25                      5.0
# 3                                 0.28                     14.0
# 4                                 0.19                      4.0
# ...                                ...                      ...
# 12049                             0.25                     18.0
# 12050                             0.26                      0.0
# 12051                             0.28                     16.0
# 12052                             0.36                      4.0
# 12053                             0.40                      6.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                            9.3                         7.6
# 1                            8.3                         6.8
# 2                            7.6                         6.0
# 3                            7.3                         5.6
# 4                            7.8                         6.0
# ...                          ...                         ...
# 12049                        6.8                         4.9
# 12050                        8.8                         6.2
# 12051                        6.2                         4.4
# 12052                        6.5                         4.9
# 12053                        7.0                         5.0
#
#        relative_humidity_2m_min (%)
# 0                                78
# 1                                50
# 2                                53
# 3                                80
# 4                                76
# ...                             ...
# 12049                            80
# 12050                            73
# 12051                            80
# 12052                            73
# 12053                            66
#
# [12054 rows x 13 columns]

# %%
#Peace River Forest / Fort St. John Hinterland
#→ 56.30, -121.00


pfad = "../data/import weather data/import data/British Columbia/open-meteo-56.27N121.05W789m-2.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
British_Columbia_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

British_Columbia_3
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      56.274162  -121.05373  1990-01-01                      -7.0
# 1      56.274162  -121.05373  1990-01-02                     -17.1
# 2      56.274162  -121.05373  1990-01-03                     -19.7
# 3      56.274162  -121.05373  1990-01-04                     -20.2
# 4      56.274162  -121.05373  1990-01-05                     -19.0
# ...          ...         ...         ...                       ...
# 12049  56.274162  -121.05373  2022-12-28                     -15.4
# 12050  56.274162  -121.05373  2022-12-29                     -15.9
# 12051  56.274162  -121.05373  2022-12-30                     -15.3
# 12052  56.274162  -121.05373  2022-12-31                     -13.9
# 12053  56.274162  -121.05373  2023-01-01                      -9.4
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -0.9                             76
# 1                        -12.8                             62
# 2                        -17.4                             68
# 3                        -18.7                             77
# 4                         -7.6                             81
# ...                        ...                            ...
# 12049                    -14.0                             79
# 12050                    -13.4                             89
# 12051                    -10.9                             87
# 12052                    -11.2                             88
# 12053                     -2.3                             84
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         3.3                              352
# 1                         0.9                               12
# 2                         2.9                               14
# 3                         3.0                               45
# 4                         4.3                              119
# ...                       ...                              ...
# 12049                     1.6                              351
# 12050                     0.0                                2
# 12051                     0.0                               75
# 12052                     0.0                              220
# 12053                     0.0                              258
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.22                     12.0
# 1                                 0.16                      5.0
# 2                                 0.11                     13.0
# 3                                 0.06                     11.0
# 4                                 0.09                      8.0
# ...                                ...                      ...
# 12049                             0.08                      6.0
# 12050                             0.06                      0.0
# 12051                             0.07                      0.0
# 12052                             0.07                      0.0
# 12053                             0.18                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           12.4                        10.5
# 1                           11.9                         7.6
# 2                           10.1                         6.9
# 3                            6.6                         4.4
# 4                           11.6                         8.4
# ...                          ...                         ...
# 12049                        5.8                         4.0
# 12050                        7.3                         4.6
# 12051                        9.5                         5.5
# 12052                        4.8                         2.6
# 12053                       14.6                        11.9
#
#        relative_humidity_2m_min (%)
# 0                                66
# 1                                53
# 2                                64
# 3                                67
# 4                                73
# ...                             ...
# 12049                            74
# 12050                            85
# 12051                            80
# 12052                            86
# 12053                            73
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Daten zusammenführen pro Provinz und Durchschnitt berechnen

# %%
# in Datetime umwandeln
for df in [British_Columbia_1, British_Columbia_2, British_Columbia_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [British_Columbia_1, British_Columbia_2, British_Columbia_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
British_Columbia_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

British_Columbia_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                 -3.766667                 0.466667
# 1     1990-01-02                -10.066667                -5.633333
# 2     1990-01-03                 -9.500000                -6.966667
# 3     1990-01-04                 -9.166667                -6.366667
# 4     1990-01-05                 -6.866667                -0.800000
# ...          ...                       ...                      ...
# 12049 2022-12-28                 -4.500000                -2.866667
# 12050 2022-12-29                 -7.900000                -4.166667
# 12051 2022-12-30                 -6.100000                -2.766667
# 12052 2022-12-31                 -5.733333                -3.100000
# 12053 2023-01-01                 -4.600000                -0.300000
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          86.000000                     72.666667
# 1                          73.333333                     57.333333
# 2                          79.000000                     65.333333
# 3                          84.000000                     75.666667
# 4                          83.666667                     72.000000
# ...                              ...                           ...
# 12049                      86.666667                     75.666667
# 12050                      88.000000                     76.666667
# 12051                      87.000000                     79.666667
# 12052                      89.000000                     81.666667
# 12053                      85.666667                     72.333333
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    1.400000                 5.666667
# 1                    1.100000                 5.000000
# 2                    4.433333                14.000000
# 3                    4.033333                12.000000
# 4                    2.666667                 6.333333
# ...                       ...                      ...
# 12049                1.900000                10.666667
# 12050                0.000000                 0.000000
# 12051                2.200000                 9.000000
# 12052                1.633333                 3.666667
# 12053                0.666667                 2.000000
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                        9.166667                  12.733333
# 1                        7.066667                  10.566667
# 2                        8.366667                  10.400000
# 3                        6.766667                   9.633333
# 4                       10.233333                  14.333333
# ...                           ...                        ...
# 12049                    4.933333                   7.800000
# 12050                    6.833333                  11.166667
# 12051                    7.900000                  10.566667
# 12052                    5.100000                   7.800000
# 12053                    7.300000                   9.800000
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           219.000000                         0.260000
# 1                           125.666667                         0.233333
# 2                           111.666667                         0.176667
# 3                           113.333333                         0.176667
# 4                           147.666667                         0.220000
# ...                                ...                              ...
# 12049                       290.333333                         0.180000
# 12050                       142.333333                         0.176667
# 12051                       171.333333                         0.193333
# 12052                       208.333333                         0.196667
# 12053                       209.666667                         0.256667
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durschnitt pro Monat

# %%
British_Columbia_mean['time'] = pd.to_datetime(British_Columbia_mean['time'])

# Monats-Durchschnitt für alle Variablen
British_Columbia_monthly_mean = (
    British_Columbia_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

British_Columbia_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                 -7.217204                -3.096774
# 1   1990-02-01                 -8.708333                -2.703571
# 2   1990-03-01                 -0.410753                 5.854839
# 3   1990-04-01                  5.446667                11.931111
# 4   1990-05-01                 10.031183                16.084946
# ..         ...                       ...                      ...
# 392 2022-09-01                 14.718889                21.870000
# 393 2022-10-01                  9.849462                15.419355
# 394 2022-11-01                 -4.906667                -1.096667
# 395 2022-12-01                -12.351613                -8.421505
# 396 2023-01-01                 -4.600000                -0.300000
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        80.827957                     67.301075
# 1                        74.023810                     55.714286
# 2                        70.774194                     46.817204
# 3                        65.322222                     38.933333
# 4                        69.774194                     42.430108
# ..                             ...                           ...
# 392                      62.866667                     34.522222
# 393                      67.139785                     42.569892
# 394                      75.155556                     59.755556
# 395                      79.559140                     68.365591
# 396                      85.666667                     72.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.897849                 5.365591
# 1                  1.233333                 4.000000
# 2                  0.783871                 2.591398
# 3                  1.227778                 3.522222
# 4                  2.725806                 6.043011
# ..                      ...                      ...
# 392                0.834444                 1.366667
# 393                0.772043                 1.978495
# 394                1.555556                 4.066667
# 395                1.718280                 5.344086
# 396                0.666667                 2.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                      8.690323                  12.411828
# 1                      8.808333                  12.864286
# 2                      7.102151                  11.177419
# 3                      6.862222                  11.044444
# 4                      6.849462                  11.625806
# ..                          ...                        ...
# 392                    7.303333                  12.341111
# 393                    8.088172                  13.237634
# 394                    8.901111                  12.875556
# 395                    7.688172                  11.604301
# 396                    7.300000                   9.800000
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         195.720430                         0.305269
# 1                         190.511905                         0.605714
# 2                         198.150538                         1.463763
# 3                         186.688889                         2.393444
# 4                         201.365591                         2.998065
# ..                               ...                              ...
# 392                       226.355556                         2.794667
# 393                       201.344086                         1.592903
# 394                       193.388889                         0.451000
# 395                       208.806452                         0.193871
# 396                       209.666667                         0.256667
#
# [397 rows x 11 columns]

# %%
import os
#Datei speichern
output_path = "../data/cleaned_British_Columbia_monthly_mean.csv"


# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

British_Columbia_monthly_mean.to_csv(output_path, index=False)

# %% [markdown]
# ### Alberta

# %%
#Fort McMurray Forest Zone
#→ 56.75, -111.45
import pandas as pd

pfad = "../data/import weather data/import data/Alberta/open-meteo-56.77N111.51W352m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Alberta_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Alberta_1
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      56.766254  -111.50943  1990-01-01                      -8.0
# 1      56.766254  -111.50943  1990-01-02                     -17.1
# 2      56.766254  -111.50943  1990-01-03                     -24.8
# 3      56.766254  -111.50943  1990-01-04                     -28.7
# 4      56.766254  -111.50943  1990-01-05                     -29.8
# ...          ...         ...         ...                       ...
# 12049  56.766254  -111.50943  2022-12-28                     -14.6
# 12050  56.766254  -111.50943  2022-12-29                     -16.0
# 12051  56.766254  -111.50943  2022-12-30                     -14.0
# 12052  56.766254  -111.50943  2022-12-31                      -9.2
# 12053  56.766254  -111.50943  2023-01-01                      -9.7
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -4.5                             84
# 1                        -13.3                             83
# 2                        -18.9                             78
# 3                        -27.3                             72
# 4                        -21.3                             76
# ...                        ...                            ...
# 12049                    -13.1                             74
# 12050                    -13.2                             82
# 12051                     -9.4                             85
# 12052                     -7.0                             88
# 12053                     -6.5                             85
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.1                              332
# 1                         0.2                              360
# 2                         0.0                              320
# 3                         0.0                              229
# 4                         0.0                              189
# ...                       ...                              ...
# 12049                     0.8                              113
# 12050                     0.3                              128
# 12051                     0.0                              150
# 12052                     0.5                              127
# 12053                     0.0                              226
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.11                      1.0
# 1                                 0.05                      2.0
# 2                                 0.04                      0.0
# 3                                 0.05                      0.0
# 4                                 0.05                      0.0
# ...                                ...                      ...
# 12049                             0.11                      6.0
# 12050                             0.07                      3.0
# 12051                             0.07                      0.0
# 12052                             0.08                      5.0
# 12053                             0.11                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           11.8                         9.7
# 1                            9.6                         4.8
# 2                            8.0                         5.7
# 3                           10.9                         6.6
# 4                           11.5                         9.0
# ...                          ...                         ...
# 12049                       11.7                         7.4
# 12050                        8.4                         5.3
# 12051                        9.2                         4.9
# 12052                        5.8                         4.0
# 12053                       11.2                         8.7
#
#        relative_humidity_2m_min (%)
# 0                                74
# 1                                78
# 2                                74
# 3                                62
# 4                                70
# ...                             ...
# 12049                            71
# 12050                            77
# 12051                            80
# 12052                            82
# 12053                            78
#
# [12054 rows x 13 columns]

# %%
#Slave Lake Wildland Area
#→ 55.28, -114.77

pfad = "../data/import weather data/import data/Alberta/open-meteo-55.29N114.76W585m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Alberta_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Alberta_2
# Out:
#        latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      55.28998  -114.75903  1990-01-01                      -3.6
# 1      55.28998  -114.75903  1990-01-02                      -8.2
# 2      55.28998  -114.75903  1990-01-03                     -14.6
# 3      55.28998  -114.75903  1990-01-04                     -17.1
# 4      55.28998  -114.75903  1990-01-05                     -16.6
# ...         ...         ...         ...                       ...
# 12049  55.28998  -114.75903  2022-12-28                     -11.0
# 12050  55.28998  -114.75903  2022-12-29                     -15.2
# 12051  55.28998  -114.75903  2022-12-30                     -11.8
# 12052  55.28998  -114.75903  2022-12-31                     -12.2
# 12053  55.28998  -114.75903  2023-01-01                      -8.7
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -2.1                             85
# 1                         -4.1                             76
# 2                        -10.4                             72
# 3                        -15.5                             72
# 4                         -8.2                             82
# ...                        ...                            ...
# 12049                    -10.0                             81
# 12050                    -13.1                             81
# 12051                     -8.8                             88
# 12052                     -9.6                             86
# 12053                     -3.2                             83
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         1.7                              295
# 1                         0.2                              330
# 2                         3.8                               16
# 3                         1.4                               76
# 4                         1.2                              136
# ...                       ...                              ...
# 12049                     4.9                              116
# 12050                     0.0                               99
# 12051                     0.0                              105
# 12052                     0.0                              107
# 12053                     0.0                              311
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.20                      8.0
# 1                                 0.20                      1.0
# 2                                 0.17                     16.0
# 3                                 0.12                      8.0
# 4                                 0.13                      5.0
# ...                                ...                      ...
# 12049                             0.15                     18.0
# 12050                             0.11                      0.0
# 12051                             0.10                      0.0
# 12052                             0.09                      0.0
# 12053                             0.18                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           14.4                         9.8
# 1                           11.9                         9.1
# 2                           13.6                        10.0
# 3                           10.2                         7.6
# 4                           17.1                        11.3
# ...                          ...                         ...
# 12049                       19.0                        11.2
# 12050                       11.5                         8.2
# 12051                       15.6                        13.1
# 12052                       14.2                         9.2
# 12053                       16.1                        10.8
#
#        relative_humidity_2m_min (%)
# 0                                74
# 1                                67
# 2                                63
# 3                                64
# 4                                78
# ...                             ...
# 12049                            76
# 12050                            70
# 12051                            83
# 12052                            78
# 12053                            75
#
# [12054 rows x 13 columns]

# %%
#Rocky Mountain House Forest Belt
#→ 52.37, -115.10

pfad = "../data/import weather data/import data/Alberta/open-meteo-52.34N115.17W1007m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Alberta_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Alberta_3
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      52.337433  -115.16666  1990-01-01                      -2.7
# 1      52.337433  -115.16666  1990-01-02                      -5.0
# 2      52.337433  -115.16666  1990-01-03                      -8.1
# 3      52.337433  -115.16666  1990-01-04                     -10.4
# 4      52.337433  -115.16666  1990-01-05                     -10.1
# ...          ...         ...         ...                       ...
# 12049  52.337433  -115.16666  2022-12-28                      -4.6
# 12050  52.337433  -115.16666  2022-12-29                      -6.4
# 12051  52.337433  -115.16666  2022-12-30                      -5.2
# 12052  52.337433  -115.16666  2022-12-31                      -3.5
# 12053  52.337433  -115.16666  2023-01-01                      -2.1
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          0.2                             69
# 1                         -2.6                             87
# 2                         -5.8                             74
# 3                         -6.7                             83
# 4                          1.6                             81
# ...                        ...                            ...
# 12049                      0.9                             91
# 12050                     -0.7                             83
# 12051                      0.4                             73
# 12052                      1.2                             77
# 12053                      2.7                             76
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              253
# 1                         1.2                              355
# 2                         0.0                              262
# 3                         0.9                              154
# 4                         0.1                              183
# ...                       ...                              ...
# 12049                     2.0                              357
# 12050                     0.2                              222
# 12051                     0.0                              223
# 12052                     0.0                              265
# 12053                     1.0                              257
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.46                      0.0
# 1                                 0.21                     10.0
# 2                                 0.26                      0.0
# 3                                 0.16                      5.0
# 4                                 0.29                      1.0
# ...                                ...                      ...
# 12049                             0.16                     10.0
# 12050                             0.27                      2.0
# 12051                             0.32                      0.0
# 12052                             0.36                      0.0
# 12053                             0.34                      5.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           15.8                         9.1
# 1                           12.3                         7.7
# 2                           11.7                         8.1
# 3                           13.6                         8.5
# 4                           11.8                         8.7
# ...                          ...                         ...
# 12049                        9.8                         6.2
# 12050                        9.2                         5.8
# 12051                       12.2                         7.8
# 12052                       12.0                         8.2
# 12053                       12.0                         8.1
#
#        relative_humidity_2m_min (%)
# 0                                58
# 1                                66
# 2                                60
# 3                                76
# 4                                65
# ...                             ...
# 12049                            77
# 12050                            56
# 12051                            55
# 12052                            64
# 12053                            52
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durschnitt pro Provinz

# %%
# in Datetime umwandeln
for df in [Alberta_1, Alberta_2, Alberta_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [Alberta_1, Alberta_2, Alberta_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
Alberta_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

Alberta_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                 -4.766667                -2.133333
# 1     1990-01-02                -10.100000                -6.666667
# 2     1990-01-03                -15.833333               -11.700000
# 3     1990-01-04                -18.733333               -16.500000
# 4     1990-01-05                -18.833333                -9.300000
# ...          ...                       ...                      ...
# 12049 2022-12-28                -10.066667                -7.400000
# 12050 2022-12-29                -12.533333                -9.000000
# 12051 2022-12-30                -10.333333                -5.933333
# 12052 2022-12-31                 -8.300000                -5.133333
# 12053 2023-01-01                 -6.833333                -2.333333
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          79.333333                     68.666667
# 1                          82.000000                     70.333333
# 2                          74.666667                     65.666667
# 3                          75.666667                     67.333333
# 4                          79.666667                     71.000000
# ...                              ...                           ...
# 12049                      82.000000                     74.666667
# 12050                      82.000000                     67.666667
# 12051                      82.000000                     72.666667
# 12052                      83.666667                     74.666667
# 12053                      81.333333                     68.333333
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    0.600000                 3.000000
# 1                    0.533333                 4.333333
# 2                    1.266667                 5.333333
# 3                    0.766667                 4.333333
# 4                    0.433333                 2.000000
# ...                       ...                      ...
# 12049                2.566667                11.333333
# 12050                0.166667                 1.666667
# 12051                0.000000                 0.000000
# 12052                0.166667                 1.666667
# 12053                0.333333                 1.666667
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                        9.533333                  14.000000
# 1                        7.200000                  11.266667
# 2                        7.933333                  11.100000
# 3                        7.566667                  11.566667
# 4                        9.666667                  13.466667
# ...                           ...                        ...
# 12049                    8.266667                  13.500000
# 12050                    6.433333                   9.700000
# 12051                    8.600000                  12.333333
# 12052                    7.133333                  10.666667
# 12053                    9.200000                  13.100000
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           293.333333                         0.256667
# 1                           348.333333                         0.153333
# 2                           199.333333                         0.156667
# 3                           153.000000                         0.110000
# 4                           169.333333                         0.156667
# ...                                ...                              ...
# 12049                       195.333333                         0.140000
# 12050                       149.666667                         0.150000
# 12051                       159.333333                         0.163333
# 12052                       166.333333                         0.176667
# 12053                       264.666667                         0.210000
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durschnitt pro Monat

# %%
Alberta_mean['time'] = pd.to_datetime(Alberta_mean['time'])

# Monats-Durchschnitt für alle Variablen
Alberta_monthly_mean = (
    Alberta_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

Alberta_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -11.569892                -6.860215
# 1   1990-02-01                -13.560714                -6.180952
# 2   1990-03-01                 -2.176344                 5.023656
# 3   1990-04-01                  2.753333                 9.282222
# 4   1990-05-01                  9.982796                16.177419
# ..         ...                       ...                      ...
# 392 2022-09-01                 14.074444                21.204444
# 393 2022-10-01                  8.090323                13.873118
# 394 2022-11-01                 -5.663333                -1.366667
# 395 2022-12-01                -16.086022               -11.305376
# 396 2023-01-01                 -6.833333                -2.333333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        76.344086                     64.795699
# 1                        71.392857                     52.857143
# 2                        67.838710                     42.827957
# 3                        64.888889                     40.122222
# 4                        65.139785                     39.204301
# ..                             ...                           ...
# 392                      64.833333                     39.666667
# 393                      65.150538                     43.483871
# 394                      69.633333                     53.433333
# 395                      75.344086                     65.043011
# 396                      81.333333                     68.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  0.592473                 2.505376
# 1                  0.458333                 1.797619
# 2                  0.488172                 1.838710
# 3                  1.252222                 3.288889
# 4                  1.895699                 3.483871
# ..                      ...                      ...
# 392                0.855556                 2.000000
# 393                0.744086                 1.806452
# 394                0.964444                 4.277778
# 395                0.983871                 4.387097
# 396                0.333333                 1.666667
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     10.409677                  15.327957
# 1                     10.897619                  16.297619
# 2                     10.551613                  15.489247
# 3                     10.631111                  16.352222
# 4                     10.335484                  16.073118
# ..                          ...                        ...
# 392                   10.297778                  15.964444
# 393                   11.341935                  18.224731
# 394                   12.106667                  17.871111
# 395                   10.149462                  15.201075
# 396                    9.200000                  13.100000
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         223.365591                         0.289140
# 1                         206.761905                         0.532976
# 2                         229.709677                         1.406667
# 3                         208.500000                         2.221222
# 4                         186.462366                         3.430645
# ..                               ...                              ...
# 392                       225.666667                         2.744333
# 393                       219.032258                         1.712258
# 394                       241.311111                         0.541778
# 395                       215.591398                         0.184946
# 396                       264.666667                         0.210000
#
# [397 rows x 11 columns]

# %% [markdown]
# ### Jahr und Monat in verschiedene Columns

# %%
# sicherstellen, dass time datetime ist
Alberta_monthly_mean['time'] = pd.to_datetime(Alberta_monthly_mean['time'])

# Jahr und Monat extrahieren
Alberta_monthly_mean['Year'] = Alberta_monthly_mean['time'].dt.year
Alberta_monthly_mean['Month'] = Alberta_monthly_mean['time'].dt.month
Alberta_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -11.569892                -6.860215
# 1   1990-02-01                -13.560714                -6.180952
# 2   1990-03-01                 -2.176344                 5.023656
# 3   1990-04-01                  2.753333                 9.282222
# 4   1990-05-01                  9.982796                16.177419
# ..         ...                       ...                      ...
# 392 2022-09-01                 14.074444                21.204444
# 393 2022-10-01                  8.090323                13.873118
# 394 2022-11-01                 -5.663333                -1.366667
# 395 2022-12-01                -16.086022               -11.305376
# 396 2023-01-01                 -6.833333                -2.333333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        76.344086                     64.795699
# 1                        71.392857                     52.857143
# 2                        67.838710                     42.827957
# 3                        64.888889                     40.122222
# 4                        65.139785                     39.204301
# ..                             ...                           ...
# 392                      64.833333                     39.666667
# 393                      65.150538                     43.483871
# 394                      69.633333                     53.433333
# 395                      75.344086                     65.043011
# 396                      81.333333                     68.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  0.592473                 2.505376
# 1                  0.458333                 1.797619
# 2                  0.488172                 1.838710
# 3                  1.252222                 3.288889
# 4                  1.895699                 3.483871
# ..                      ...                      ...
# 392                0.855556                 2.000000
# 393                0.744086                 1.806452
# 394                0.964444                 4.277778
# 395                0.983871                 4.387097
# 396                0.333333                 1.666667
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     10.409677                  15.327957
# 1                     10.897619                  16.297619
# 2                     10.551613                  15.489247
# 3                     10.631111                  16.352222
# 4                     10.335484                  16.073118
# ..                          ...                        ...
# 392                   10.297778                  15.964444
# 393                   11.341935                  18.224731
# 394                   12.106667                  17.871111
# 395                   10.149462                  15.201075
# 396                    9.200000                  13.100000
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         223.365591                         0.289140  1990
# 1                         206.761905                         0.532976  1990
# 2                         229.709677                         1.406667  1990
# 3                         208.500000                         2.221222  1990
# 4                         186.462366                         3.430645  1990
# ..                               ...                              ...   ...
# 392                       225.666667                         2.744333  2022
# 393                       219.032258                         1.712258  2022
# 394                       241.311111                         0.541778  2022
# 395                       215.591398                         0.184946  2022
# 396                       264.666667                         0.210000  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os
#Datei speichern
output_path = "../data/cleaned_Alberta_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

Alberta_monthly_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## Quebec

# %%
#Chibougamau / Eeyou Istchee Boreal Forest
#→ 49.90,-74.38

pfad = "../data/import weather data/import data/Quebec/open-meteo-49.88N74.35W429m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Quebec_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Quebec_1
# Out:
#         latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      49.876976  -74.34784  1990-01-01                     -12.8
# 1      49.876976  -74.34784  1990-01-02                     -15.9
# 2      49.876976  -74.34784  1990-01-03                     -12.0
# 3      49.876976  -74.34784  1990-01-04                      -4.2
# 4      49.876976  -74.34784  1990-01-05                     -18.6
# ...          ...        ...         ...                       ...
# 12049  49.876976  -74.34784  2022-12-28                     -13.7
# 12050  49.876976  -74.34784  2022-12-29                      -8.1
# 12051  49.876976  -74.34784  2022-12-30                       1.7
# 12052  49.876976  -74.34784  2022-12-31                      -0.3
# 12053  49.876976  -74.34784  2023-01-01                      -5.8
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -8.1                             81
# 1                         -6.4                             81
# 2                         -6.0                             78
# 3                         -1.0                             86
# 4                         -9.0                             75
# ...                        ...                            ...
# 12049                     -8.6                             80
# 12050                     -3.6                             88
# 12051                      4.4                             91
# 12052                      4.2                             89
# 12053                     -3.4                             86
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         4.7                              300
# 1                         2.3                              243
# 2                         0.9                              283
# 3                         2.6                              223
# 4                         0.0                              276
# ...                       ...                              ...
# 12049                     1.5                              167
# 12050                    12.6                              130
# 12051                     1.1                              197
# 12052                     0.2                              259
# 12053                     0.0                              322
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.20                     15.0
# 1                                 0.21                     13.0
# 2                                 0.26                      5.0
# 3                                 0.28                     16.0
# 4                                 0.20                      0.0
# ...                                ...                      ...
# 12049                             0.19                      9.0
# 12050                             0.16                     17.0
# 12051                             0.23                      8.0
# 12052                             0.21                      2.0
# 12053                             0.20                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           25.4                        17.1
# 1                           23.7                        16.6
# 2                           20.6                        13.0
# 3                           19.1                        16.7
# 4                           20.1                        14.2
# ...                          ...                         ...
# 12049                       12.6                         9.3
# 12050                       22.3                        16.8
# 12051                       23.6                        17.2
# 12052                       23.0                        14.2
# 12053                       12.5                         9.5
#
#        relative_humidity_2m_min (%)
# 0                                69
# 1                                75
# 2                                68
# 3                                78
# 4                                64
# ...                             ...
# 12049                            77
# 12050                            86
# 12051                            88
# 12052                            84
# 12053                            78
#
# [12054 rows x 13 columns]

# %%
#La Grande / Nord-du-Québec Feuerzonen
#→ 53.60, -76.10

pfad = "../data/import weather data/import data/Quebec/open-meteo-53.60N76.03W237m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Quebec_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Quebec_2
# Out:
#        latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      53.60281  -76.034485  1990-01-01                     -18.5
# 1      53.60281  -76.034485  1990-01-02                     -21.9
# 2      53.60281  -76.034485  1990-01-03                     -22.7
# 3      53.60281  -76.034485  1990-01-04                     -16.4
# 4      53.60281  -76.034485  1990-01-05                     -27.5
# ...         ...         ...         ...                       ...
# 12049  53.60281  -76.034485  2022-12-28                     -18.4
# 12050  53.60281  -76.034485  2022-12-29                     -15.2
# 12051  53.60281  -76.034485  2022-12-30                      -4.0
# 12052  53.60281  -76.034485  2022-12-31                      -6.3
# 12053  53.60281  -76.034485  2023-01-01                     -11.3
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                        -13.7                             79
# 1                        -16.0                             78
# 2                        -17.3                             78
# 3                         -8.5                             77
# 4                        -23.1                             74
# ...                        ...                            ...
# 12049                    -17.0                             79
# 12050                     -9.1                             78
# 12051                      0.5                             92
# 12052                     -0.8                             85
# 12053                     -9.6                             84
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         1.2                              298
# 1                         1.7                              195
# 2                         0.1                              254
# 3                         2.9                              219
# 4                         0.0                              255
# ...                       ...                              ...
# 12049                     0.7                              202
# 12050                     0.8                              119
# 12051                     6.4                              156
# 12052                     2.7                              249
# 12053                     0.4                              245
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.11                      7.0
# 1                                 0.11                     10.0
# 2                                 0.09                      1.0
# 3                                 0.21                      9.0
# 4                                 0.09                      0.0
# ...                                ...                      ...
# 12049                             0.13                      7.0
# 12050                             0.21                      5.0
# 12051                             0.11                     15.0
# 12052                             0.21                     23.0
# 12053                             0.12                      4.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           21.9                        15.3
# 1                           16.2                        11.3
# 2                           15.1                        10.3
# 3                           29.6                        23.4
# 4                           19.8                        16.3
# ...                          ...                         ...
# 12049                       17.3                         9.8
# 12050                       21.4                        16.0
# 12051                       17.5                        14.2
# 12052                       23.1                        17.8
# 12053                       10.8                         8.0
#
#        relative_humidity_2m_min (%)
# 0                                72
# 1                                76
# 2                                71
# 3                                68
# 4                                66
# ...                             ...
# 12049                            74
# 12050                            71
# 12051                            83
# 12052                            78
# 12053                            80
#
# [12054 rows x 13 columns]

# %%
#Mauricie Boreal Forest Belt
#→ 47.00, -72.80

pfad = "../data/import weather data/import data/Quebec/open-meteo-46.99N72.76W381m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Quebec_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Quebec_3
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      46.994724  -72.759766  1990-01-01                      -4.3
# 1      46.994724  -72.759766  1990-01-02                     -12.7
# 2      46.994724  -72.759766  1990-01-03                      -2.9
# 3      46.994724  -72.759766  1990-01-04                      -1.6
# 4      46.994724  -72.759766  1990-01-05                      -7.3
# ...          ...         ...         ...                       ...
# 12049  46.994724  -72.759766  2022-12-28                     -11.8
# 12050  46.994724  -72.759766  2022-12-29                      -4.4
# 12051  46.994724  -72.759766  2022-12-30                       2.1
# 12052  46.994724  -72.759766  2022-12-31                       2.7
# 12053  46.994724  -72.759766  2023-01-01                      -0.3
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          0.6                             85
# 1                         -4.4                             76
# 2                         -1.1                             81
# 3                          0.4                             93
# 4                          0.2                             72
# ...                        ...                            ...
# 12049                     -6.5                             86
# 12050                     -1.5                             92
# 12051                      5.2                             90
# 12052                      4.4                             93
# 12053                      1.2                             89
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         8.0                              279
# 1                         0.0                              259
# 2                         0.0                              245
# 3                         7.5                              179
# 4                         3.1                              305
# ...                       ...                              ...
# 12049                     3.5                              163
# 12050                     4.3                              138
# 12051                     0.3                              179
# 12052                     9.1                              177
# 12053                     6.0                              345
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.35                     19.0
# 1                                 0.32                      0.0
# 2                                 0.44                      0.0
# 3                                 0.19                      9.0
# 4                                 0.47                      3.0
# ...                                ...                      ...
# 12049                             0.14                     15.0
# 12050                             0.19                     13.0
# 12051                             0.29                      3.0
# 12052                             0.23                     19.0
# 12053                             0.34                     15.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           25.5                        17.3
# 1                           22.7                        14.3
# 2                           14.0                        10.3
# 3                           13.7                        12.5
# 4                           21.3                        13.5
# ...                          ...                         ...
# 12049                       10.7                         8.9
# 12050                       16.3                        10.3
# 12051                       12.8                        11.0
# 12052                       11.8                         6.6
# 12053                       15.4                        10.7
#
#        relative_humidity_2m_min (%)
# 0                                64
# 1                                69
# 2                                68
# 3                                88
# 4                                56
# ...                             ...
# 12049                            78
# 12050                            83
# 12051                            83
# 12052                            78
# 12053                            71
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durschnitt pro Provinz

# %%
# in Datetime umwandeln
for df in [Quebec_1, Quebec_2, Quebec_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [Quebec_1, Quebec_2, Quebec_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
Quebec_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

Quebec_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                -11.866667                -7.066667
# 1     1990-01-02                -16.833333                -8.933333
# 2     1990-01-03                -12.533333                -8.133333
# 3     1990-01-04                 -7.400000                -3.033333
# 4     1990-01-05                -17.800000               -10.633333
# ...          ...                       ...                      ...
# 12049 2022-12-28                -14.633333               -10.700000
# 12050 2022-12-29                 -9.233333                -4.733333
# 12051 2022-12-30                 -0.066667                 3.366667
# 12052 2022-12-31                 -1.300000                 2.600000
# 12053 2023-01-01                 -5.800000                -3.933333
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          81.666667                     68.333333
# 1                          78.333333                     73.333333
# 2                          79.000000                     69.000000
# 3                          85.333333                     78.000000
# 4                          73.666667                     62.000000
# ...                              ...                           ...
# 12049                      81.666667                     76.333333
# 12050                      86.000000                     80.000000
# 12051                      91.000000                     84.666667
# 12052                      89.000000                     80.000000
# 12053                      86.333333                     76.333333
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    4.633333                13.666667
# 1                    1.333333                 7.666667
# 2                    0.333333                 2.000000
# 3                    4.333333                11.333333
# 4                    1.033333                 1.000000
# ...                       ...                      ...
# 12049                1.900000                10.333333
# 12050                5.900000                11.666667
# 12051                2.600000                 8.666667
# 12052                4.000000                14.666667
# 12053                2.133333                 6.333333
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                       16.566667                  24.266667
# 1                       14.066667                  20.866667
# 2                       11.200000                  16.566667
# 3                       17.533333                  20.800000
# 4                       14.666667                  20.400000
# ...                           ...                        ...
# 12049                    9.333333                  13.533333
# 12050                   14.366667                  20.000000
# 12051                   14.133333                  17.966667
# 12052                   12.866667                  19.300000
# 12053                    9.400000                  12.900000
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           292.333333                         0.220000
# 1                           232.333333                         0.213333
# 2                           260.666667                         0.263333
# 3                           207.000000                         0.226667
# 4                           278.666667                         0.253333
# ...                                ...                              ...
# 12049                       177.333333                         0.153333
# 12050                       129.000000                         0.186667
# 12051                       177.333333                         0.210000
# 12052                       228.333333                         0.216667
# 12053                       304.000000                         0.220000
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durchschnitt pro Monat

# %%
Quebec_mean['time'] = pd.to_datetime(Quebec_mean['time'])

# Monats-Durchschnitt für alle Variablen
Quebec_monthly_mean = (
    Quebec_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

Quebec_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -15.113978               -10.651613
# 1   1990-02-01                -18.552381               -13.453571
# 2   1990-03-01                 -9.580645                -4.570968
# 3   1990-04-01                 -1.653333                 2.888889
# 4   1990-05-01                  5.680645                10.969892
# ..         ...                       ...                      ...
# 392 2022-09-01                 11.757778                16.245556
# 393 2022-10-01                  6.641935                10.644086
# 394 2022-11-01                 -1.573333                 1.440000
# 395 2022-12-01                 -8.340860                -5.121505
# 396 2023-01-01                 -5.800000                -3.933333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        77.838710                     67.838710
# 1                        71.190476                     57.190476
# 2                        72.978495                     55.774194
# 3                        76.755556                     58.488889
# 4                        66.236559                     44.075269
# ..                             ...                           ...
# 392                      76.266667                     55.833333
# 393                      78.784946                     59.989247
# 394                      80.000000                     67.333333
# 395                      80.752688                     71.193548
# 396                      86.333333                     76.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.864516                 5.172043
# 1                  1.430952                 3.952381
# 2                  1.294624                 3.505376
# 3                  2.013333                 4.555556
# 4                  2.343011                 4.204301
# ..                      ...                      ...
# 392                2.881111                 4.522222
# 393                3.208602                 6.043011
# 394                3.557778                 8.600000
# 395                3.148387                 7.838710
# 396                2.133333                 6.333333
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     13.095699                  18.507527
# 1                     13.436905                  18.475000
# 2                     13.438710                  18.306452
# 3                     12.527778                  18.077778
# 4                     11.766667                  17.237634
# ..                          ...                        ...
# 392                   12.747778                  18.021111
# 393                   14.753763                  21.101075
# 394                   15.678889                  22.050000
# 395                   15.170968                  20.787097
# 396                    9.400000                  12.900000
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         200.591398                         0.255376
# 1                         226.773810                         0.341310
# 2                         235.010753                         0.829462
# 3                         191.288889                         1.523111
# 4                         189.731183                         2.760000
# ..                               ...                              ...
# 392                       229.688889                         2.159000
# 393                       194.924731                         1.209892
# 394                       219.822222                         0.574556
# 395                       178.548387                         0.297849
# 396                       304.000000                         0.220000
#
# [397 rows x 11 columns]

# %%
# Jahr und Monat extrahieren
Quebec_monthly_mean['Year'] = Quebec_monthly_mean['time'].dt.year
Quebec_monthly_mean['Month'] = Quebec_monthly_mean['time'].dt.month
Quebec_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -15.113978               -10.651613
# 1   1990-02-01                -18.552381               -13.453571
# 2   1990-03-01                 -9.580645                -4.570968
# 3   1990-04-01                 -1.653333                 2.888889
# 4   1990-05-01                  5.680645                10.969892
# ..         ...                       ...                      ...
# 392 2022-09-01                 11.757778                16.245556
# 393 2022-10-01                  6.641935                10.644086
# 394 2022-11-01                 -1.573333                 1.440000
# 395 2022-12-01                 -8.340860                -5.121505
# 396 2023-01-01                 -5.800000                -3.933333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        77.838710                     67.838710
# 1                        71.190476                     57.190476
# 2                        72.978495                     55.774194
# 3                        76.755556                     58.488889
# 4                        66.236559                     44.075269
# ..                             ...                           ...
# 392                      76.266667                     55.833333
# 393                      78.784946                     59.989247
# 394                      80.000000                     67.333333
# 395                      80.752688                     71.193548
# 396                      86.333333                     76.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.864516                 5.172043
# 1                  1.430952                 3.952381
# 2                  1.294624                 3.505376
# 3                  2.013333                 4.555556
# 4                  2.343011                 4.204301
# ..                      ...                      ...
# 392                2.881111                 4.522222
# 393                3.208602                 6.043011
# 394                3.557778                 8.600000
# 395                3.148387                 7.838710
# 396                2.133333                 6.333333
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     13.095699                  18.507527
# 1                     13.436905                  18.475000
# 2                     13.438710                  18.306452
# 3                     12.527778                  18.077778
# 4                     11.766667                  17.237634
# ..                          ...                        ...
# 392                   12.747778                  18.021111
# 393                   14.753763                  21.101075
# 394                   15.678889                  22.050000
# 395                   15.170968                  20.787097
# 396                    9.400000                  12.900000
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         200.591398                         0.255376  1990
# 1                         226.773810                         0.341310  1990
# 2                         235.010753                         0.829462  1990
# 3                         191.288889                         1.523111  1990
# 4                         189.731183                         2.760000  1990
# ..                               ...                              ...   ...
# 392                       229.688889                         2.159000  2022
# 393                       194.924731                         1.209892  2022
# 394                       219.822222                         0.574556  2022
# 395                       178.548387                         0.297849  2022
# 396                       304.000000                         0.220000  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os
#Datei speichern
output_path = "../data/cleaned_Quebec_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

Quebec_monthly_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## Ontario

# %%
#Red Lake – eine der aktivsten Brandregionen:
#→ 51.02, -93.82

pfad = "../data/import weather data/import data/Ontario/open-meteo-51.00N93.86W356m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Ontario_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Ontario_1
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      51.001755  -93.864044  1990-01-01                     -12.7
# 1      51.001755  -93.864044  1990-01-02                      -6.2
# 2      51.001755  -93.864044  1990-01-03                     -10.5
# 3      51.001755  -93.864044  1990-01-04                     -17.7
# 4      51.001755  -93.864044  1990-01-05                     -22.5
# ...          ...         ...         ...                       ...
# 12049  51.001755  -93.864044  2022-12-28                     -11.2
# 12050  51.001755  -93.864044  2022-12-29                      -5.9
# 12051  51.001755  -93.864044  2022-12-30                     -10.9
# 12052  51.001755  -93.864044  2022-12-31                     -15.2
# 12053  51.001755  -93.864044  2023-01-01                     -10.2
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -8.7                             80
# 1                         -4.3                             83
# 2                         -7.7                             85
# 3                        -13.4                             77
# 4                        -21.0                             76
# ...                        ...                            ...
# 12049                     -6.5                             83
# 12050                     -4.7                             89
# 12051                     -5.0                             82
# 12052                    -11.7                             80
# 12053                     -7.8                             86
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              208
# 1                         0.0                              278
# 2                         3.7                               25
# 3                         0.1                              289
# 4                         0.0                              272
# ...                       ...                              ...
# 12049                     0.8                               95
# 12050                     0.9                              109
# 12051                     2.3                              265
# 12052                     0.0                              162
# 12053                     0.0                               74
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.20                      0.0
# 1                                 0.28                      0.0
# 2                                 0.16                      9.0
# 3                                 0.17                      1.0
# 4                                 0.13                      0.0
# ...                                ...                      ...
# 12049                             0.22                      5.0
# 12050                             0.15                      5.0
# 12051                             0.19                     10.0
# 12052                             0.18                      0.0
# 12053                             0.14                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           27.4                        14.3
# 1                           21.8                        14.8
# 2                           20.2                        11.6
# 3                           18.7                        12.6
# 4                           10.9                         8.8
# ...                          ...                         ...
# 12049                       17.3                        15.5
# 12050                       14.1                         7.8
# 12051                       15.3                        12.1
# 12052                       12.3                         8.5
# 12053                        8.4                         5.0
#
#        relative_humidity_2m_min (%)
# 0                                71
# 1                                74
# 2                                76
# 3                                67
# 4                                66
# ...                             ...
# 12049                            80
# 12050                            86
# 12051                            71
# 12052                            71
# 12053                            82
#
# [12054 rows x 13 columns]

# %%
#Sioux Lookout Boreal Forest
#→ 50.10, -91.90

pfad = "../data/import weather data/import data/Ontario/open-meteo-50.09N91.89W371m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Ontario_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Ontario_2
# Out:
#        latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      50.08787  -91.88812  1990-01-01                     -11.8
# 1      50.08787  -91.88812  1990-01-02                      -3.5
# 2      50.08787  -91.88812  1990-01-03                      -4.7
# 3      50.08787  -91.88812  1990-01-04                     -14.1
# 4      50.08787  -91.88812  1990-01-05                     -20.6
# ...         ...        ...         ...                       ...
# 12049  50.08787  -91.88812  2022-12-28                      -8.4
# 12050  50.08787  -91.88812  2022-12-29                      -4.3
# 12051  50.08787  -91.88812  2022-12-30                      -6.8
# 12052  50.08787  -91.88812  2022-12-31                     -13.8
# 12053  50.08787  -91.88812  2023-01-01                      -8.2
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -8.4                             80
# 1                         -1.5                             82
# 2                         -2.6                             88
# 3                         -7.7                             78
# 4                        -18.3                             77
# ...                        ...                            ...
# 12049                     -4.1                             85
# 12050                     -2.8                             90
# 12051                     -3.2                             86
# 12052                    -10.9                             83
# 12053                     -6.5                             86
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              226
# 1                         0.0                              257
# 2                         3.0                              107
# 3                         0.1                              284
# 4                         0.0                              282
# ...                       ...                              ...
# 12049                     0.4                               95
# 12050                     1.2                              102
# 12051                     1.6                              268
# 12052                     0.0                              170
# 12053                     0.3                               37
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.22                      0.0
# 1                                 0.36                      0.0
# 2                                 0.23                      9.0
# 3                                 0.22                      1.0
# 4                                 0.14                      0.0
# ...                                ...                      ...
# 12049                             0.19                      3.0
# 12050                             0.17                      1.0
# 12051                             0.20                     11.0
# 12052                             0.18                      0.0
# 12053                             0.18                      3.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           25.5                        13.0
# 1                           24.3                        15.8
# 2                           21.3                        12.8
# 3                           20.5                        12.9
# 4                           11.5                         7.2
# ...                          ...                         ...
# 12049                       16.2                        12.1
# 12050                       15.9                         7.6
# 12051                       15.9                        11.6
# 12052                       12.0                         7.9
# 12053                        8.3                         5.9
#
#        relative_humidity_2m_min (%)
# 0                                70
# 1                                72
# 2                                80
# 3                                68
# 4                                65
# ...                             ...
# 12049                            80
# 12050                            85
# 12051                            75
# 12052                            75
# 12053                            80
#
# [12054 rows x 13 columns]

# %%
#Temagami Forest Region
#→ 47.06, -80.06

pfad = "../data/import weather data/import data/Ontario/open-meteo-47.07N80.05W347m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Ontario_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Ontario_3
# Out:
#         latitude longitude        time  temperature_2m_mean (°C)  \
# 0      47.065025  -80.0488  1990-01-01                     -11.5
# 1      47.065025  -80.0488  1990-01-02                      -7.3
# 2      47.065025  -80.0488  1990-01-03                      -4.6
# 3      47.065025  -80.0488  1990-01-04                      -0.4
# 4      47.065025  -80.0488  1990-01-05                      -8.5
# ...          ...       ...         ...                       ...
# 12049  47.065025  -80.0488  2022-12-28                      -3.5
# 12050  47.065025  -80.0488  2022-12-29                       1.6
# 12051  47.065025  -80.0488  2022-12-30                       4.3
# 12052  47.065025  -80.0488  2022-12-31                       0.2
# 12053  47.065025  -80.0488  2023-01-01                      -1.6
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                        -10.6                             77
# 1                         -2.5                             82
# 2                         -1.2                             91
# 3                          0.6                             91
# 4                         -4.0                             80
# ...                        ...                            ...
# 12049                     -0.7                             89
# 12050                      4.1                             85
# 12051                      5.6                             96
# 12052                      3.4                             91
# 12053                     -0.7                             88
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         2.8                              318
# 1                         0.0                              226
# 2                         0.0                              202
# 3                         5.3                              243
# 4                         0.0                              287
# ...                       ...                              ...
# 12049                     7.9                              204
# 12050                     0.8                              195
# 12051                     1.2                              209
# 12052                     0.0                              278
# 12053                     0.0                              312
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.32                     11.0
# 1                                 0.41                      0.0
# 2                                 0.26                      0.0
# 3                                 0.23                     10.0
# 4                                 0.27                      0.0
# ...                                ...                      ...
# 12049                             0.22                     16.0
# 12050                             0.50                      2.0
# 12051                             0.23                      9.0
# 12052                             0.26                      0.0
# 12053                             0.34                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           16.9                        13.9
# 1                           26.0                        19.5
# 2                           20.0                        12.7
# 3                           19.5                        13.1
# 4                           13.4                         8.8
# ...                          ...                         ...
# 12049                       17.9                        13.2
# 12050                       18.6                        16.5
# 12051                       22.1                        17.8
# 12052                       16.3                         7.1
# 12053                       10.5                         7.5
#
#        relative_humidity_2m_min (%)
# 0                                65
# 1                                75
# 2                                82
# 3                                82
# 4                                67
# ...                             ...
# 12049                            85
# 12050                            78
# 12051                            87
# 12052                            81
# 12053                            74
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durschnitt pro Provinz

# %%
# in Datetime umwandeln
for df in [Ontario_1, Ontario_2, Ontario_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [Ontario_1, Ontario_2, Ontario_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
Ontario_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

Ontario_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                -12.000000                -9.233333
# 1     1990-01-02                 -5.666667                -2.766667
# 2     1990-01-03                 -6.600000                -3.833333
# 3     1990-01-04                -10.733333                -6.833333
# 4     1990-01-05                -17.200000               -14.433333
# ...          ...                       ...                      ...
# 12049 2022-12-28                 -7.700000                -3.766667
# 12050 2022-12-29                 -2.866667                -1.133333
# 12051 2022-12-30                 -4.466667                -0.866667
# 12052 2022-12-31                 -9.600000                -6.400000
# 12053 2023-01-01                 -6.666667                -5.000000
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          79.000000                     68.666667
# 1                          82.333333                     73.666667
# 2                          88.000000                     79.333333
# 3                          82.000000                     72.333333
# 4                          77.666667                     66.000000
# ...                              ...                           ...
# 12049                      85.666667                     81.666667
# 12050                      88.000000                     83.000000
# 12051                      88.000000                     77.666667
# 12052                      84.666667                     75.666667
# 12053                      86.666667                     78.666667
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    0.933333                 3.666667
# 1                    0.000000                 0.000000
# 2                    2.233333                 6.000000
# 3                    1.833333                 4.000000
# 4                    0.000000                 0.000000
# ...                       ...                      ...
# 12049                3.033333                 8.000000
# 12050                0.966667                 2.666667
# 12051                1.700000                10.000000
# 12052                0.000000                 0.000000
# 12053                0.100000                 1.000000
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                       13.733333                  23.266667
# 1                       16.700000                  24.033333
# 2                       12.366667                  20.500000
# 3                       12.866667                  19.566667
# 4                        8.266667                  11.933333
# ...                           ...                        ...
# 12049                   13.600000                  17.133333
# 12050                   10.633333                  16.200000
# 12051                   13.833333                  17.766667
# 12052                    7.833333                  13.533333
# 12053                    6.133333                   9.066667
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           250.666667                         0.246667
# 1                           253.666667                         0.350000
# 2                           111.333333                         0.216667
# 3                           272.000000                         0.206667
# 4                           280.333333                         0.180000
# ...                                ...                              ...
# 12049                       131.333333                         0.210000
# 12050                       135.333333                         0.273333
# 12051                       247.333333                         0.206667
# 12052                       203.333333                         0.206667
# 12053                       141.000000                         0.220000
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durchschnitt Monat

# %%
Ontario_mean['time'] = pd.to_datetime(Ontario_mean['time'])

# Monats-Durchschnitt für alle Variablen
Ontario_monthly_mean = (
    Ontario_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

Ontario_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -11.455914                -7.695699
# 1   1990-02-01                -13.639286                -8.882143
# 2   1990-03-01                 -5.796774                -1.204301
# 3   1990-04-01                  1.244444                 6.698889
# 4   1990-05-01                  8.473118                14.366667
# ..         ...                       ...                      ...
# 392 2022-09-01                 13.878889                18.278889
# 393 2022-10-01                  6.759140                10.692473
# 394 2022-11-01                 -1.020000                 1.848889
# 395 2022-12-01                -10.265591                -7.196774
# 396 2023-01-01                 -6.666667                -5.000000
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        80.537634                     69.537634
# 1                        73.797619                     58.964286
# 2                        73.548387                     55.645161
# 3                        71.833333                     50.066667
# 4                        64.602151                     40.924731
# ..                             ...                           ...
# 392                      75.988889                     55.977778
# 393                      77.225806                     59.129032
# 394                      79.200000                     66.111111
# 395                      80.548387                     71.892473
# 396                      86.666667                     78.666667
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.743011                 4.290323
# 1                  0.841667                 2.511905
# 2                  1.098925                 2.365591
# 3                  1.940000                 3.155556
# 4                  2.208602                 3.387097
# ..                      ...                      ...
# 392                2.564444                 4.388889
# 393                1.839785                 5.225806
# 394                2.225556                 6.377778
# 395                1.762366                 6.967742
# 396                0.100000                 1.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     12.251613                  18.006452
# 1                     12.951190                  18.021429
# 2                     12.943011                  17.933333
# 3                     12.797778                  18.601111
# 4                     10.852688                  15.767742
# ..                          ...                        ...
# 392                   12.587778                  18.076667
# 393                   14.139785                  19.958065
# 394                   14.858889                  20.478889
# 395                   13.605376                  18.395699
# 396                    6.133333                   9.066667
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         208.849462                         0.272688
# 1                         211.559524                         0.465357
# 2                         201.989247                         1.026774
# 3                         213.355556                         1.925222
# 4                         168.763441                         3.197634
# ..                               ...                              ...
# 392                       201.588889                         2.366667
# 393                       199.634409                         1.278280
# 394                       201.688889                         0.604778
# 395                       192.784946                         0.262796
# 396                       141.000000                         0.220000
#
# [397 rows x 11 columns]

# %%
# Jahr und Monat extrahieren
Ontario_monthly_mean['Year'] = Ontario_monthly_mean['time'].dt.year
Ontario_monthly_mean['Month'] = Ontario_monthly_mean['time'].dt.month
Ontario_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -11.455914                -7.695699
# 1   1990-02-01                -13.639286                -8.882143
# 2   1990-03-01                 -5.796774                -1.204301
# 3   1990-04-01                  1.244444                 6.698889
# 4   1990-05-01                  8.473118                14.366667
# ..         ...                       ...                      ...
# 392 2022-09-01                 13.878889                18.278889
# 393 2022-10-01                  6.759140                10.692473
# 394 2022-11-01                 -1.020000                 1.848889
# 395 2022-12-01                -10.265591                -7.196774
# 396 2023-01-01                 -6.666667                -5.000000
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        80.537634                     69.537634
# 1                        73.797619                     58.964286
# 2                        73.548387                     55.645161
# 3                        71.833333                     50.066667
# 4                        64.602151                     40.924731
# ..                             ...                           ...
# 392                      75.988889                     55.977778
# 393                      77.225806                     59.129032
# 394                      79.200000                     66.111111
# 395                      80.548387                     71.892473
# 396                      86.666667                     78.666667
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.743011                 4.290323
# 1                  0.841667                 2.511905
# 2                  1.098925                 2.365591
# 3                  1.940000                 3.155556
# 4                  2.208602                 3.387097
# ..                      ...                      ...
# 392                2.564444                 4.388889
# 393                1.839785                 5.225806
# 394                2.225556                 6.377778
# 395                1.762366                 6.967742
# 396                0.100000                 1.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     12.251613                  18.006452
# 1                     12.951190                  18.021429
# 2                     12.943011                  17.933333
# 3                     12.797778                  18.601111
# 4                     10.852688                  15.767742
# ..                          ...                        ...
# 392                   12.587778                  18.076667
# 393                   14.139785                  19.958065
# 394                   14.858889                  20.478889
# 395                   13.605376                  18.395699
# 396                    6.133333                   9.066667
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         208.849462                         0.272688  1990
# 1                         211.559524                         0.465357  1990
# 2                         201.989247                         1.026774  1990
# 3                         213.355556                         1.925222  1990
# 4                         168.763441                         3.197634  1990
# ..                               ...                              ...   ...
# 392                       201.588889                         2.366667  2022
# 393                       199.634409                         1.278280  2022
# 394                       201.688889                         0.604778  2022
# 395                       192.784946                         0.262796  2022
# 396                       141.000000                         0.220000  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os

#Datei speichern
output_path = "../data/cleaned_Ontario_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

Ontario_monthly_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## Saskatchewan

# %%
#Prince Albert National Park
#→ 53.96, -106.22

pfad = "../data/import weather data/import data/Saskatchewan/open-meteo-53.95N106.19W532m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Saskatchewan_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Saskatchewan_1
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      53.954304  -106.18956  1990-01-01                      -8.4
# 1      53.954304  -106.18956  1990-01-02                     -11.3
# 2      53.954304  -106.18956  1990-01-03                     -15.9
# 3      53.954304  -106.18956  1990-01-04                     -23.6
# 4      53.954304  -106.18956  1990-01-05                     -23.6
# ...          ...         ...         ...                       ...
# 12049  53.954304  -106.18956  2022-12-28                     -16.8
# 12050  53.954304  -106.18956  2022-12-29                     -18.3
# 12051  53.954304  -106.18956  2022-12-30                     -15.9
# 12052  53.954304  -106.18956  2022-12-31                     -12.9
# 12053  53.954304  -106.18956  2023-01-01                     -10.9
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -4.6                             86
# 1                         -5.2                             83
# 2                        -14.1                             82
# 3                        -19.3                             77
# 4                        -21.3                             77
# ...                        ...                            ...
# 12049                    -15.7                             78
# 12050                    -17.6                             76
# 12051                    -12.6                             81
# 12052                    -11.4                             88
# 12053                     -8.1                             87
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.1                              242
# 1                         0.0                                4
# 2                         2.2                              324
# 3                         0.0                              287
# 4                         0.0                              250
# ...                       ...                              ...
# 12049                     4.4                               63
# 12050                     0.2                              335
# 12051                     0.1                              176
# 12052                     0.0                              104
# 12053                     0.0                              269
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.18                      1.0
# 1                                 0.11                      0.0
# 2                                 0.09                     10.0
# 3                                 0.08                      0.0
# 4                                 0.08                      0.0
# ...                                ...                      ...
# 12049                             0.12                     24.0
# 12050                             0.09                      2.0
# 12051                             0.12                      1.0
# 12052                             0.09                      0.0
# 12053                             0.11                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           20.1                        14.9
# 1                           13.4                         7.9
# 2                           13.4                         6.6
# 3                           13.3                         7.6
# 4                           11.7                         8.2
# ...                          ...                         ...
# 12049                       12.8                        10.7
# 12050                        9.4                         6.0
# 12051                       11.6                         8.4
# 12052                       11.6                         5.8
# 12053                       10.2                         6.3
#
#        relative_humidity_2m_min (%)
# 0                                79
# 1                                76
# 2                                72
# 3                                66
# 4                                74
# ...                             ...
# 12049                            73
# 12050                            69
# 12051                            75
# 12052                            83
# 12053                            81
#
# [12054 rows x 13 columns]

# %%
#La Ronge borealer Wald
# 55.10, -105.30

pfad = "../data/import weather data/import data/Saskatchewan/open-meteo-55.08N105.45W370m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Saskatchewan_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Saskatchewan_2
# Out:
#         latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      55.079086  -105.4491  1990-01-01                     -11.2
# 1      55.079086  -105.4491  1990-01-02                     -13.8
# 2      55.079086  -105.4491  1990-01-03                     -17.8
# 3      55.079086  -105.4491  1990-01-04                     -25.0
# 4      55.079086  -105.4491  1990-01-05                     -26.6
# ...          ...        ...         ...                       ...
# 12049  55.079086  -105.4491  2022-12-28                     -17.5
# 12050  55.079086  -105.4491  2022-12-29                     -19.2
# 12051  55.079086  -105.4491  2022-12-30                     -19.4
# 12052  55.079086  -105.4491  2022-12-31                     -13.7
# 12053  55.079086  -105.4491  2023-01-01                     -11.7
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -9.1                             82
# 1                         -9.7                             79
# 2                        -16.0                             80
# 3                        -20.9                             75
# 4                        -22.2                             74
# ...                        ...                            ...
# 12049                    -15.9                             77
# 12050                    -18.7                             74
# 12051                    -15.7                             79
# 12052                    -11.4                             83
# 12053                     -8.9                             85
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              242
# 1                         0.0                              353
# 2                         0.8                              313
# 3                         0.0                              280
# 4                         0.0                              255
# ...                       ...                              ...
# 12049                     3.4                               79
# 12050                     0.5                                2
# 12051                     0.0                              116
# 12052                     0.0                              131
# 12053                     0.0                              249
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.18                      0.0
# 1                                 0.11                      0.0
# 2                                 0.08                      6.0
# 3                                 0.09                      0.0
# 4                                 0.08                      0.0
# ...                                ...                      ...
# 12049                             0.17                     23.0
# 12050                             0.08                      5.0
# 12051                             0.09                      0.0
# 12052                             0.08                      0.0
# 12053                             0.10                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           19.8                        14.4
# 1                           14.9                         8.1
# 2                           15.1                         6.7
# 3                           15.6                        10.3
# 4                           12.5                         9.5
# ...                          ...                         ...
# 12049                       20.8                        17.8
# 12050                       10.7                         6.2
# 12051                       11.0                         6.1
# 12052                        8.9                         4.4
# 12053                        7.3                         5.3
#
#        relative_humidity_2m_min (%)
# 0                                74
# 1                                74
# 2                                72
# 3                                70
# 4                                67
# ...                             ...
# 12049                            74
# 12050                            72
# 12051                            72
# 12052                            73
# 12053                            77
#
# [12054 rows x 13 columns]

# %%
#Meadow Lake Provincial Park
#→ 54.14, -108.44
pfad = "../data/import weather data/import data/Saskatchewan/open-meteo-54.17N108.39W483m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Saskatchewan_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Saskatchewan_3
# Out:
#       latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      54.1652  -108.38522  1990-01-01                      -5.8
# 1      54.1652  -108.38522  1990-01-02                     -11.6
# 2      54.1652  -108.38522  1990-01-03                     -17.1
# 3      54.1652  -108.38522  1990-01-04                     -24.5
# 4      54.1652  -108.38522  1990-01-05                     -23.0
# ...        ...         ...         ...                       ...
# 12049  54.1652  -108.38522  2022-12-28                     -14.6
# 12050  54.1652  -108.38522  2022-12-29                     -15.9
# 12051  54.1652  -108.38522  2022-12-30                     -15.6
# 12052  54.1652  -108.38522  2022-12-31                     -12.1
# 12053  54.1652  -108.38522  2023-01-01                     -10.4
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -2.5                             87
# 1                         -4.7                             86
# 2                        -13.7                             82
# 3                        -18.9                             76
# 4                        -16.3                             80
# ...                        ...                            ...
# 12049                    -14.2                             77
# 12050                    -14.9                             74
# 12051                    -11.3                             85
# 12052                    -10.6                             87
# 12053                     -7.5                             86
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.2                              254
# 1                         0.0                               18
# 2                         1.4                              338
# 3                         0.0                              299
# 4                         0.0                              211
# ...                       ...                              ...
# 12049                     3.1                               59
# 12050                     0.2                               46
# 12051                     0.0                              120
# 12052                     0.0                               25
# 12053                     0.0                              243
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.17                      2.0
# 1                                 0.10                      0.0
# 2                                 0.10                      6.0
# 3                                 0.08                      0.0
# 4                                 0.08                      0.0
# ...                                ...                      ...
# 12049                             0.17                     16.0
# 12050                             0.09                      2.0
# 12051                             0.09                      0.0
# 12052                             0.09                      0.0
# 12053                             0.11                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           14.8                        10.7
# 1                           11.7                         7.3
# 2                            9.9                         5.9
# 3                            9.3                         4.2
# 4                            9.5                         6.5
# ...                          ...                         ...
# 12049                       16.6                        11.9
# 12050                        7.3                         3.6
# 12051                        7.7                         3.9
# 12052                        6.3                         3.7
# 12053                       13.9                         8.9
#
#        relative_humidity_2m_min (%)
# 0                                75
# 1                                76
# 2                                71
# 3                                68
# 4                                75
# ...                             ...
# 12049                            73
# 12050                            72
# 12051                            77
# 12052                            82
# 12053                            85
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durchschnitt pro Provinz

# %%
for df in [Saskatchewan_1, Saskatchewan_2, Saskatchewan_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [Saskatchewan_1, Saskatchewan_2, Saskatchewan_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
Saskatchewan_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

Saskatchewan_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                 -8.466667                -5.400000
# 1     1990-01-02                -12.233333                -6.533333
# 2     1990-01-03                -16.933333               -14.600000
# 3     1990-01-04                -24.366667               -19.700000
# 4     1990-01-05                -24.400000               -19.933333
# ...          ...                       ...                      ...
# 12049 2022-12-28                -16.300000               -15.266667
# 12050 2022-12-29                -17.800000               -17.066667
# 12051 2022-12-30                -16.966667               -13.200000
# 12052 2022-12-31                -12.900000               -11.133333
# 12053 2023-01-01                -11.000000                -8.166667
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          85.000000                     76.000000
# 1                          82.666667                     75.333333
# 2                          81.333333                     71.666667
# 3                          76.000000                     68.000000
# 4                          77.000000                     72.000000
# ...                              ...                           ...
# 12049                      77.333333                     73.333333
# 12050                      74.666667                     71.000000
# 12051                      81.666667                     74.666667
# 12052                      86.000000                     79.333333
# 12053                      86.000000                     81.000000
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    0.100000                 1.000000
# 1                    0.000000                 0.000000
# 2                    1.466667                 7.333333
# 3                    0.000000                 0.000000
# 4                    0.000000                 0.000000
# ...                       ...                      ...
# 12049                3.633333                21.000000
# 12050                0.300000                 3.000000
# 12051                0.033333                 0.333333
# 12052                0.000000                 0.000000
# 12053                0.000000                 0.000000
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                       13.333333                  18.233333
# 1                        7.766667                  13.333333
# 2                        6.400000                  12.800000
# 3                        7.366667                  12.733333
# 4                        8.066667                  11.233333
# ...                           ...                        ...
# 12049                   13.466667                  16.733333
# 12050                    5.266667                   9.133333
# 12051                    6.133333                  10.100000
# 12052                    4.633333                   8.933333
# 12053                    6.833333                  10.466667
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           246.000000                         0.176667
# 1                           125.000000                         0.106667
# 2                           325.000000                         0.090000
# 3                           288.666667                         0.083333
# 4                           238.666667                         0.080000
# ...                                ...                              ...
# 12049                        67.000000                         0.153333
# 12050                       127.666667                         0.086667
# 12051                       137.333333                         0.100000
# 12052                        86.666667                         0.086667
# 12053                       253.666667                         0.106667
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durchschnitt pro Monat

# %%
Saskatchewan_mean['time'] = pd.to_datetime(Saskatchewan_mean['time'])

# Monats-Durchschnitt für alle Variablen
Saskatchewan_monthly_mean = (
    Saskatchewan_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

Saskatchewan_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -14.477419               -10.540860
# 1   1990-02-01                -17.078571               -11.145238
# 2   1990-03-01                 -4.513978                 0.586022
# 3   1990-04-01                  0.884444                 6.568889
# 4   1990-05-01                  8.650538                15.210753
# ..         ...                       ...                      ...
# 392 2022-09-01                 14.188889                20.246667
# 393 2022-10-01                  6.903226                11.948387
# 394 2022-11-01                 -6.371111                -3.567778
# 395 2022-12-01                -18.429032               -15.166667
# 396 2023-01-01                -11.000000                -8.166667
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        80.612903                     71.344086
# 1                        74.785714                     61.059524
# 2                        76.827957                     60.666667
# 3                        69.633333                     47.388889
# 4                        66.903226                     40.580645
# ..                             ...                           ...
# 392                      68.466667                     44.211111
# 393                      65.752688                     46.279570
# 394                      85.377778                     75.822222
# 395                      78.860215                     71.903226
# 396                      86.000000                     81.000000
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  0.587097                 2.247312
# 1                  0.551190                 1.916667
# 2                  0.411828                 1.473118
# 3                  2.073333                 3.788889
# 4                  1.137634                 2.354839
# ..                      ...                      ...
# 392                1.002222                 2.022222
# 393                0.373118                 1.817204
# 394                1.778889                 6.577778
# 395                0.920430                 4.333333
# 396                0.000000                 0.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     10.807527                  15.573118
# 1                     10.839286                  15.148810
# 2                     12.686022                  17.097849
# 3                     11.662222                  16.811111
# 4                     10.504301                  15.512903
# ..                          ...                        ...
# 392                   11.503333                  18.657778
# 393                   12.601075                  17.882796
# 394                   13.566667                  18.736667
# 395                   10.873118                  15.650538
# 396                    6.833333                  10.466667
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         226.860215                         0.174301
# 1                         212.750000                         0.356071
# 2                         205.569892                         1.018065
# 3                         199.288889                         1.848111
# 4                         160.483871                         3.359677
# ..                               ...                              ...
# 392                       213.755556                         2.666222
# 393                       208.225806                         1.591183
# 394                       194.233333                         0.278000
# 395                       182.301075                         0.124516
# 396                       253.666667                         0.106667
#
# [397 rows x 11 columns]

# %%
# Jahr und Monat extrahieren
Saskatchewan_monthly_mean['Year'] = Saskatchewan_monthly_mean['time'].dt.year
Saskatchewan_monthly_mean['Month'] = Saskatchewan_monthly_mean['time'].dt.month
Saskatchewan_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -14.477419               -10.540860
# 1   1990-02-01                -17.078571               -11.145238
# 2   1990-03-01                 -4.513978                 0.586022
# 3   1990-04-01                  0.884444                 6.568889
# 4   1990-05-01                  8.650538                15.210753
# ..         ...                       ...                      ...
# 392 2022-09-01                 14.188889                20.246667
# 393 2022-10-01                  6.903226                11.948387
# 394 2022-11-01                 -6.371111                -3.567778
# 395 2022-12-01                -18.429032               -15.166667
# 396 2023-01-01                -11.000000                -8.166667
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        80.612903                     71.344086
# 1                        74.785714                     61.059524
# 2                        76.827957                     60.666667
# 3                        69.633333                     47.388889
# 4                        66.903226                     40.580645
# ..                             ...                           ...
# 392                      68.466667                     44.211111
# 393                      65.752688                     46.279570
# 394                      85.377778                     75.822222
# 395                      78.860215                     71.903226
# 396                      86.000000                     81.000000
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  0.587097                 2.247312
# 1                  0.551190                 1.916667
# 2                  0.411828                 1.473118
# 3                  2.073333                 3.788889
# 4                  1.137634                 2.354839
# ..                      ...                      ...
# 392                1.002222                 2.022222
# 393                0.373118                 1.817204
# 394                1.778889                 6.577778
# 395                0.920430                 4.333333
# 396                0.000000                 0.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     10.807527                  15.573118
# 1                     10.839286                  15.148810
# 2                     12.686022                  17.097849
# 3                     11.662222                  16.811111
# 4                     10.504301                  15.512903
# ..                          ...                        ...
# 392                   11.503333                  18.657778
# 393                   12.601075                  17.882796
# 394                   13.566667                  18.736667
# 395                   10.873118                  15.650538
# 396                    6.833333                  10.466667
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         226.860215                         0.174301  1990
# 1                         212.750000                         0.356071  1990
# 2                         205.569892                         1.018065  1990
# 3                         199.288889                         1.848111  1990
# 4                         160.483871                         3.359677  1990
# ..                               ...                              ...   ...
# 392                       213.755556                         2.666222  2022
# 393                       208.225806                         1.591183  2022
# 394                       194.233333                         0.278000  2022
# 395                       182.301075                         0.124516  2022
# 396                       253.666667                         0.106667  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os

#Datei speichern
output_path = "../data/cleaned_Saskatchewan_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

Saskatchewan_monthly_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## Manitoba

# %%
#Thompson boreale Waldregion
#→ 55.74, -97.86

pfad = "../data/import weather data/import data/Manitoba/open-meteo-55.71N97.87W206m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Manitoba_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Manitoba_1
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      55.711773  -97.865845  1990-01-01                     -17.0
# 1      55.711773  -97.865845  1990-01-02                     -18.9
# 2      55.711773  -97.865845  1990-01-03                     -22.6
# 3      55.711773  -97.865845  1990-01-04                     -26.0
# 4      55.711773  -97.865845  1990-01-05                     -28.8
# ...          ...         ...         ...                       ...
# 12049  55.711773  -97.865845  2022-12-28                     -25.5
# 12050  55.711773  -97.865845  2022-12-29                     -17.8
# 12051  55.711773  -97.865845  2022-12-30                     -14.8
# 12052  55.711773  -97.865845  2022-12-31                     -17.8
# 12053  55.711773  -97.865845  2023-01-01                     -16.0
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                        -13.6                             78
# 1                        -13.8                             78
# 2                        -21.6                             77
# 3                        -22.0                             73
# 4                        -25.1                             72
# ...                        ...                            ...
# 12049                    -20.6                             74
# 12050                    -15.5                             77
# 12051                    -13.8                             82
# 12052                    -15.3                             82
# 12053                    -14.3                             82
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              178
# 1                         0.0                              320
# 2                         2.5                              315
# 3                         0.0                              287
# 4                         0.0                              268
# ...                       ...                              ...
# 12049                     0.0                               63
# 12050                     6.9                               58
# 12051                     2.7                                7
# 12052                     0.0                              165
# 12053                     0.0                              284
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.12                      0.0
# 1                                 0.11                      0.0
# 2                                 0.05                     13.0
# 3                                 0.08                      0.0
# 4                                 0.08                      0.0
# ...                                ...                      ...
# 12049                             0.09                      0.0
# 12050                             0.12                     24.0
# 12051                             0.06                     20.0
# 12052                             0.07                      0.0
# 12053                             0.07                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           15.5                        10.2
# 1                           15.3                        10.8
# 2                            9.2                         4.8
# 3                           12.7                        11.8
# 4                           13.7                        11.9
# ...                          ...                         ...
# 12049                       17.4                        13.2
# 12050                       15.3                        10.6
# 12051                        6.9                         3.7
# 12052                       10.8                         8.0
# 12053                        8.6                         5.1
#
#        relative_humidity_2m_min (%)
# 0                                76
# 1                                71
# 2                                71
# 3                                64
# 4                                65
# ...                             ...
# 12049                            68
# 12050                            75
# 12051                            74
# 12052                            72
# 12053                            73
#
# [12054 rows x 13 columns]

# %%
#Flin Flon – waldreich, feueranfällig
#→ 54.77, -101.87

pfad = "../data/import weather data/import data/Manitoba/open-meteo-54.80N101.94W338m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Manitoba_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Manitoba_2
# Out:
#        latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      54.79789  -101.94058  1990-01-01                     -14.3
# 1      54.79789  -101.94058  1990-01-02                     -16.5
# 2      54.79789  -101.94058  1990-01-03                     -19.6
# 3      54.79789  -101.94058  1990-01-04                     -24.9
# 4      54.79789  -101.94058  1990-01-05                     -27.5
# ...         ...         ...         ...                       ...
# 12049  54.79789  -101.94058  2022-12-28                     -20.9
# 12050  54.79789  -101.94058  2022-12-29                     -19.8
# 12051  54.79789  -101.94058  2022-12-30                     -19.1
# 12052  54.79789  -101.94058  2022-12-31                     -16.3
# 12053  54.79789  -101.94058  2023-01-01                     -14.0
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                        -10.6                             79
# 1                        -10.8                             78
# 2                        -19.3                             78
# 3                        -21.4                             75
# 4                        -25.1                             72
# ...                        ...                            ...
# 12049                    -19.3                             76
# 12050                    -18.0                             74
# 12051                    -17.5                             77
# 12052                    -13.3                             82
# 12053                    -12.4                             84
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              191
# 1                         0.0                              340
# 2                         1.9                              338
# 3                         0.0                              288
# 4                         0.0                              269
# ...                       ...                              ...
# 12049                     4.1                               64
# 12050                     2.9                              358
# 12051                     0.5                              248
# 12052                     0.0                              133
# 12053                     0.3                              324
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.17                      0.0
# 1                                 0.13                      0.0
# 2                                 0.08                      9.0
# 3                                 0.09                      0.0
# 4                                 0.09                      0.0
# ...                                ...                      ...
# 12049                             0.11                     13.0
# 12050                             0.10                     18.0
# 12051                             0.07                      5.0
# 12052                             0.10                      0.0
# 12053                             0.09                      3.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           18.0                        12.9
# 1                           17.1                         9.9
# 2                           12.5                         5.3
# 3                           13.3                        11.3
# 4                           14.5                        10.6
# ...                          ...                         ...
# 12049                       15.1                        13.2
# 12050                        9.6                         7.2
# 12051                        8.6                         5.1
# 12052                       12.7                         8.4
# 12053                        7.1                         4.6
#
#        relative_humidity_2m_min (%)
# 0                                75
# 1                                71
# 2                                73
# 3                                68
# 4                                66
# ...                             ...
# 12049                            74
# 12050                            69
# 12051                            71
# 12052                            78
# 12053                            75
#
# [12054 rows x 13 columns]

# %%
#Atikaki Provincial Wilderness
#→ 51.23, -95.28

pfad = "../data/import weather data/import data/Manitoba/open-meteo-51.21N95.34W324m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Manitoba_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Manitoba_3
# Out:
#        latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      51.21265  -95.341705  1990-01-01                     -13.0
# 1      51.21265  -95.341705  1990-01-02                      -7.2
# 2      51.21265  -95.341705  1990-01-03                     -12.4
# 3      51.21265  -95.341705  1990-01-04                     -18.9
# 4      51.21265  -95.341705  1990-01-05                     -23.6
# ...         ...         ...         ...                       ...
# 12049  51.21265  -95.341705  2022-12-28                     -11.0
# 12050  51.21265  -95.341705  2022-12-29                      -6.0
# 12051  51.21265  -95.341705  2022-12-30                     -14.2
# 12052  51.21265  -95.341705  2022-12-31                     -14.2
# 12053  51.21265  -95.341705  2023-01-01                      -8.9
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                         -5.6                             80
# 1                         -3.5                             84
# 2                        -10.6                             83
# 3                        -15.5                             79
# 4                        -20.9                             76
# ...                        ...                            ...
# 12049                     -6.2                             81
# 12050                     -5.0                             89
# 12051                     -9.8                             80
# 12052                     -7.0                             84
# 12053                     -6.8                             87
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         0.0                              201
# 1                         0.0                              295
# 2                         3.7                              360
# 3                         0.4                              286
# 4                         0.0                              261
# ...                       ...                              ...
# 12049                     1.9                               97
# 12050                     3.5                              123
# 12051                     1.3                              259
# 12052                     0.0                              143
# 12053                     0.0                              120
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.23                      0.0
# 1                                 0.22                      0.0
# 2                                 0.16                      9.0
# 3                                 0.13                      3.0
# 4                                 0.11                      0.0
# ...                                ...                      ...
# 12049                             0.24                      8.0
# 12050                             0.15                      9.0
# 12051                             0.15                      7.0
# 12052                             0.17                      0.0
# 12053                             0.14                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           24.2                        14.7
# 1                           19.9                        12.3
# 2                           17.5                        11.0
# 3                           12.2                         9.9
# 4                            9.6                         7.4
# ...                          ...                         ...
# 12049                       17.5                        14.4
# 12050                       13.3                         7.3
# 12051                       11.8                        10.1
# 12052                       11.0                         8.5
# 12053                        8.2                         4.6
#
#        relative_humidity_2m_min (%)
# 0                                68
# 1                                71
# 2                                71
# 3                                65
# 4                                65
# ...                             ...
# 12049                            77
# 12050                            84
# 12051                            72
# 12052                            78
# 12053                            82
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durchschnitt pro Provinz

# %%
for df in [Manitoba_1, Manitoba_2, Manitoba_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [Manitoba_1, Manitoba_2, Manitoba_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
Manitoba_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

Manitoba_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                -14.766667                -9.933333
# 1     1990-01-02                -14.200000                -9.366667
# 2     1990-01-03                -18.200000               -17.166667
# 3     1990-01-04                -23.266667               -19.633333
# 4     1990-01-05                -26.633333               -23.700000
# ...          ...                       ...                      ...
# 12049 2022-12-28                -19.133333               -15.366667
# 12050 2022-12-29                -14.533333               -12.833333
# 12051 2022-12-30                -16.033333               -13.700000
# 12052 2022-12-31                -16.100000               -11.866667
# 12053 2023-01-01                -12.966667               -11.166667
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          79.000000                     73.000000
# 1                          80.000000                     71.000000
# 2                          79.333333                     71.666667
# 3                          75.666667                     65.666667
# 4                          73.333333                     65.333333
# ...                              ...                           ...
# 12049                      77.000000                     73.000000
# 12050                      80.000000                     76.000000
# 12051                      79.666667                     72.333333
# 12052                      82.666667                     76.000000
# 12053                      84.333333                     76.666667
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    0.000000                 0.000000
# 1                    0.000000                 0.000000
# 2                    2.700000                10.333333
# 3                    0.133333                 1.000000
# 4                    0.000000                 0.000000
# ...                       ...                      ...
# 12049                2.000000                 7.000000
# 12050                4.433333                17.000000
# 12051                1.500000                10.666667
# 12052                0.000000                 0.000000
# 12053                0.100000                 1.000000
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                       12.600000                  19.233333
# 1                       11.000000                  17.433333
# 2                        7.033333                  13.066667
# 3                       11.000000                  12.733333
# 4                        9.966667                  12.600000
# ...                           ...                        ...
# 12049                   13.600000                  16.666667
# 12050                    8.366667                  12.733333
# 12051                    6.300000                   9.100000
# 12052                    8.300000                  11.500000
# 12053                    4.766667                   7.966667
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           190.000000                         0.173333
# 1                           318.333333                         0.153333
# 2                           337.666667                         0.096667
# 3                           287.000000                         0.100000
# 4                           266.000000                         0.093333
# ...                                ...                              ...
# 12049                        74.666667                         0.146667
# 12050                       179.666667                         0.123333
# 12051                       171.333333                         0.093333
# 12052                       147.000000                         0.113333
# 12053                       242.666667                         0.100000
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durchschnitt in Monat

# %%
Manitoba_mean['time'] = pd.to_datetime(Manitoba_mean['time'])

# Monats-Durchschnitt für alle Variablen
Manitoba_monthly_mean = (
    Manitoba_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

Manitoba_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -18.223656               -14.378495
# 1   1990-02-01                -19.783333               -14.930952
# 2   1990-03-01                 -6.825806                -1.859140
# 3   1990-04-01                 -1.973333                 3.901111
# 4   1990-05-01                  7.700000                14.404301
# ..         ...                       ...                      ...
# 392 2022-09-01                 13.111111                18.485556
# 393 2022-10-01                  4.529032                 8.666667
# 394 2022-11-01                 -7.207778                -3.997778
# 395 2022-12-01                -18.241935               -15.137634
# 396 2023-01-01                -12.966667               -11.166667
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        77.451613                     68.376344
# 1                        71.809524                     57.797619
# 2                        72.612903                     55.666667
# 3                        69.088889                     49.211111
# 4                        61.473118                     36.720430
# ..                             ...                           ...
# 392                      73.200000                     49.755556
# 393                      76.290323                     57.666667
# 394                      82.388889                     70.700000
# 395                      78.892473                     71.462366
# 396                      84.333333                     76.666667
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  0.907527                 2.559140
# 1                  0.423810                 1.642857
# 2                  0.759140                 1.860215
# 3                  1.784444                 3.166667
# 4                  0.822581                 1.978495
# ..                      ...                      ...
# 392                1.392222                 2.766667
# 393                1.848387                 4.322581
# 394                1.785556                 6.844444
# 395                0.986022                 5.053763
# 396                0.100000                 1.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     10.686022                  15.416129
# 1                     11.214286                  16.030952
# 2                     13.917204                  18.629032
# 3                     12.524444                  17.714444
# 4                     10.708602                  15.726882
# ..                          ...                        ...
# 392                   12.102222                  17.478889
# 393                   13.473118                  19.130108
# 394                   12.364444                  17.466667
# 395                   10.958065                  14.741935
# 396                    4.766667                   7.966667
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         218.311828                         0.155591
# 1                         216.785714                         0.304167
# 2                         206.903226                         0.898925
# 3                         205.144444                         1.615333
# 4                         164.086022                         3.379892
# ..                               ...                              ...
# 392                       212.455556                         2.404111
# 393                       221.548387                         1.118065
# 394                       195.233333                         0.308889
# 395                       197.107527                         0.126667
# 396                       242.666667                         0.100000
#
# [397 rows x 11 columns]

# %%
# Jahr und Monat extrahieren
Manitoba_monthly_mean['Year'] = Manitoba_monthly_mean['time'].dt.year
Manitoba_monthly_mean['Month'] = Manitoba_monthly_mean['time'].dt.month
Manitoba_monthly_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -18.223656               -14.378495
# 1   1990-02-01                -19.783333               -14.930952
# 2   1990-03-01                 -6.825806                -1.859140
# 3   1990-04-01                 -1.973333                 3.901111
# 4   1990-05-01                  7.700000                14.404301
# ..         ...                       ...                      ...
# 392 2022-09-01                 13.111111                18.485556
# 393 2022-10-01                  4.529032                 8.666667
# 394 2022-11-01                 -7.207778                -3.997778
# 395 2022-12-01                -18.241935               -15.137634
# 396 2023-01-01                -12.966667               -11.166667
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        77.451613                     68.376344
# 1                        71.809524                     57.797619
# 2                        72.612903                     55.666667
# 3                        69.088889                     49.211111
# 4                        61.473118                     36.720430
# ..                             ...                           ...
# 392                      73.200000                     49.755556
# 393                      76.290323                     57.666667
# 394                      82.388889                     70.700000
# 395                      78.892473                     71.462366
# 396                      84.333333                     76.666667
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  0.907527                 2.559140
# 1                  0.423810                 1.642857
# 2                  0.759140                 1.860215
# 3                  1.784444                 3.166667
# 4                  0.822581                 1.978495
# ..                      ...                      ...
# 392                1.392222                 2.766667
# 393                1.848387                 4.322581
# 394                1.785556                 6.844444
# 395                0.986022                 5.053763
# 396                0.100000                 1.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     10.686022                  15.416129
# 1                     11.214286                  16.030952
# 2                     13.917204                  18.629032
# 3                     12.524444                  17.714444
# 4                     10.708602                  15.726882
# ..                          ...                        ...
# 392                   12.102222                  17.478889
# 393                   13.473118                  19.130108
# 394                   12.364444                  17.466667
# 395                   10.958065                  14.741935
# 396                    4.766667                   7.966667
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         218.311828                         0.155591  1990
# 1                         216.785714                         0.304167  1990
# 2                         206.903226                         0.898925  1990
# 3                         205.144444                         1.615333  1990
# 4                         164.086022                         3.379892  1990
# ..                               ...                              ...   ...
# 392                       212.455556                         2.404111  2022
# 393                       221.548387                         1.118065  2022
# 394                       195.233333                         0.308889  2022
# 395                       197.107527                         0.126667  2022
# 396                       242.666667                         0.100000  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os

#Datei speichern
output_path = "../data/cleaned_Manitoba_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

Manitoba_monthly_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## New Brunswick

# %%
#Miramichi Hinterland Forest
#→ 46.98, -65.52

pfad = "../data/import weather data/import data/New Brunswick/open-meteo-46.99N65.45W39m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
New_Brunswick_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

New_Brunswick_1
# Out:
#         latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      46.994724  -65.45456  1990-01-01                      -0.5
# 1      46.994724  -65.45456  1990-01-02                      -9.3
# 2      46.994724  -65.45456  1990-01-03                      -5.5
# 3      46.994724  -65.45456  1990-01-04                      -4.7
# 4      46.994724  -65.45456  1990-01-05                      -1.7
# ...          ...        ...         ...                       ...
# 12049  46.994724  -65.45456  2022-12-28                     -11.2
# 12050  46.994724  -65.45456  2022-12-29                      -8.7
# 12051  46.994724  -65.45456  2022-12-30                      -0.3
# 12052  46.994724  -65.45456  2022-12-31                       4.8
# 12053  46.994724  -65.45456  2023-01-01                       1.4
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          2.9                             92
# 1                         -3.0                             62
# 2                         -1.9                             76
# 3                          1.9                             84
# 4                          3.2                             74
# ...                        ...                            ...
# 12049                     -6.3                             77
# 12050                     -5.0                             84
# 12051                      5.1                             86
# 12052                      7.5                             90
# 12053                      2.6                             98
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                        13.0                              214
# 1                         0.0                              271
# 2                         0.0                              259
# 3                         0.1                              187
# 4                         2.6                              261
# ...                       ...                              ...
# 12049                     0.4                              247
# 12050                     1.6                              285
# 12051                     1.4                              186
# 12052                     0.1                              223
# 12053                    23.8                               15
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.24                     16.0
# 1                                 0.69                      0.0
# 2                                 0.54                      0.0
# 3                                 0.35                      1.0
# 4                                 0.65                      5.0
# ...                                ...                      ...
# 12049                             0.28                      4.0
# 12050                             0.19                      6.0
# 12051                             0.38                      5.0
# 12052                             0.38                      1.0
# 12053                             0.11                     23.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           25.0                        13.8
# 1                           26.3                        21.1
# 2                           20.3                        14.5
# 3                           16.2                        11.4
# 4                           23.9                        17.8
# ...                          ...                         ...
# 12049                       14.1                         8.5
# 12050                        9.7                         5.4
# 12051                       12.6                         7.1
# 12052                       18.6                        14.3
# 12053                       19.7                        10.3
#
#        relative_humidity_2m_min (%)
# 0                                69
# 1                                53
# 2                                54
# 3                                79
# 4                                53
# ...                             ...
# 12049                            65
# 12050                            71
# 12051                            76
# 12052                            84
# 12053                            88
#
# [12054 rows x 13 columns]

# %%
#Mount Carleton Provincial Park
#→ 47.39, -66.86

pfad = "../data/import weather data/import data/New Brunswick/open-meteo-47.42N66.69W593m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
New_Brunswick_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

New_Brunswick_2
# Out:
#        latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      47.41652  -66.68851  1990-01-01                      -1.4
# 1      47.41652  -66.68851  1990-01-02                     -13.9
# 2      47.41652  -66.68851  1990-01-03                      -8.3
# 3      47.41652  -66.68851  1990-01-04                      -5.6
# 4      47.41652  -66.68851  1990-01-05                      -6.3
# ...         ...        ...         ...                       ...
# 12049  47.41652  -66.68851  2022-12-28                     -15.7
# 12050  47.41652  -66.68851  2022-12-29                      -9.5
# 12051  47.41652  -66.68851  2022-12-30                      -1.4
# 12052  47.41652  -66.68851  2022-12-31                       3.7
# 12053  47.41652  -66.68851  2023-01-01                       0.2
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          1.4                             93
# 1                         -8.7                             70
# 2                         -6.1                             79
# 3                          0.1                             84
# 4                          0.8                             77
# ...                        ...                            ...
# 12049                    -10.0                             81
# 12050                     -7.1                             88
# 12051                      3.2                             91
# 12052                      4.7                             92
# 12053                      2.2                             98
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                        13.3                              223
# 1                         0.0                              284
# 2                         0.0                              283
# 3                         0.5                              205
# 4                         3.8                              276
# ...                       ...                              ...
# 12049                     1.2                              246
# 12050                     4.3                              219
# 12051                     0.9                              212
# 12052                     4.9                              238
# 12053                    21.6                               16
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.22                     18.0
# 1                                 0.45                      0.0
# 2                                 0.45                      0.0
# 3                                 0.33                      2.0
# 4                                 0.42                      7.0
# ...                                ...                      ...
# 12049                             0.20                      8.0
# 12050                             0.17                     11.0
# 12051                             0.24                      5.0
# 12052                             0.28                     21.0
# 12053                             0.13                     23.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           29.5                        18.2
# 1                           33.5                        28.0
# 2                           26.0                        21.5
# 3                           16.8                        12.6
# 4                           25.0                        20.9
# ...                          ...                         ...
# 12049                       14.6                        10.2
# 12050                       10.9                         5.3
# 12051                       15.9                        13.6
# 12052                       19.4                        14.7
# 12053                       15.3                         8.3
#
#        relative_humidity_2m_min (%)
# 0                                75
# 1                                63
# 2                                59
# 3                                78
# 4                                59
# ...                             ...
# 12049                            70
# 12050                            75
# 12051                            87
# 12052                            87
# 12053                            89
#
# [12054 rows x 13 columns]

# %%
#Northumberland County Boreal Edge
#→ 46.96, -65.06

pfad = "../data/import weather data/import data/New Brunswick/open-meteo-46.99N65.02W25m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
New_Brunswick_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

New_Brunswick_3
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      46.994724  -65.016235  1990-01-01                       0.4
# 1      46.994724  -65.016235  1990-01-02                      -8.8
# 2      46.994724  -65.016235  1990-01-03                      -5.5
# 3      46.994724  -65.016235  1990-01-04                      -4.3
# 4      46.994724  -65.016235  1990-01-05                      -1.5
# ...          ...         ...         ...                       ...
# 12049  46.994724  -65.016235  2022-12-28                     -10.9
# 12050  46.994724  -65.016235  2022-12-29                      -8.6
# 12051  46.994724  -65.016235  2022-12-30                       0.1
# 12052  46.994724  -65.016235  2022-12-31                       5.4
# 12053  46.994724  -65.016235  2023-01-01                       1.8
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          3.3                             92
# 1                         -1.9                             64
# 2                         -2.3                             77
# 3                          2.1                             83
# 4                          3.1                             75
# ...                        ...                            ...
# 12049                     -6.3                             74
# 12050                     -5.0                             86
# 12051                      6.0                             86
# 12052                      7.8                             88
# 12053                      3.4                             98
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                        15.4                              209
# 1                         0.0                              269
# 2                         0.0                              257
# 3                         0.1                              189
# 4                         2.4                              260
# ...                       ...                              ...
# 12049                     0.6                              253
# 12050                     1.0                              269
# 12051                     1.6                              187
# 12052                     0.1                              228
# 12053                    25.1                                9
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.26                     18.0
# 1                                 0.74                      0.0
# 2                                 0.57                      0.0
# 3                                 0.41                      1.0
# 4                                 0.69                      5.0
# ...                                ...                      ...
# 12049                             0.33                      6.0
# 12050                             0.24                      6.0
# 12051                             0.39                      7.0
# 12052                             0.47                      1.0
# 12053                             0.11                     24.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           26.6                        19.5
# 1                           32.0                        27.3
# 2                           23.0                        20.0
# 3                           21.3                        14.8
# 4                           29.9                        23.1
# ...                          ...                         ...
# 12049                       17.8                         9.4
# 12050                       11.2                         6.4
# 12051                       16.9                         9.9
# 12052                       21.1                        15.3
# 12053                       24.2                        12.4
#
#        relative_humidity_2m_min (%)
# 0                                73
# 1                                56
# 2                                60
# 3                                76
# 4                                56
# ...                             ...
# 12049                            63
# 12050                            70
# 12051                            72
# 12052                            82
# 12053                            93
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durchschnitt pro Provinz

# %%
for df in [New_Brunswick_1, New_Brunswick_2, New_Brunswick_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [New_Brunswick_1, New_Brunswick_2, New_Brunswick_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
New_Brunswick_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

New_Brunswick_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                 -0.500000                 2.533333
# 1     1990-01-02                -10.666667                -4.533333
# 2     1990-01-03                 -6.433333                -3.433333
# 3     1990-01-04                 -4.866667                 1.366667
# 4     1990-01-05                 -3.166667                 2.366667
# ...          ...                       ...                      ...
# 12049 2022-12-28                -12.600000                -7.533333
# 12050 2022-12-29                 -8.933333                -5.700000
# 12051 2022-12-30                 -0.533333                 4.766667
# 12052 2022-12-31                  4.633333                 6.666667
# 12053 2023-01-01                  1.133333                 2.733333
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          92.333333                     72.333333
# 1                          65.333333                     57.333333
# 2                          77.333333                     57.666667
# 3                          83.666667                     77.666667
# 4                          75.333333                     56.000000
# ...                              ...                           ...
# 12049                      77.333333                     66.000000
# 12050                      86.000000                     72.000000
# 12051                      87.666667                     78.333333
# 12052                      90.000000                     84.333333
# 12053                      98.000000                     90.000000
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                   13.900000                17.333333
# 1                    0.000000                 0.000000
# 2                    0.000000                 0.000000
# 3                    0.233333                 1.333333
# 4                    2.933333                 5.666667
# ...                       ...                      ...
# 12049                0.733333                 6.000000
# 12050                2.300000                 7.666667
# 12051                1.300000                 5.666667
# 12052                1.700000                 7.666667
# 12053               23.500000                23.333333
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                       17.166667                  27.033333
# 1                       25.466667                  30.600000
# 2                       18.666667                  23.100000
# 3                       12.933333                  18.100000
# 4                       20.600000                  26.266667
# ...                           ...                        ...
# 12049                    9.366667                  15.500000
# 12050                    5.700000                  10.600000
# 12051                   10.200000                  15.133333
# 12052                   14.766667                  19.700000
# 12053                   10.333333                  19.733333
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           215.333333                         0.240000
# 1                           274.666667                         0.626667
# 2                           266.333333                         0.520000
# 3                           193.666667                         0.363333
# 4                           265.666667                         0.586667
# ...                                ...                              ...
# 12049                       248.666667                         0.270000
# 12050                       257.666667                         0.200000
# 12051                       195.000000                         0.336667
# 12052                       229.666667                         0.376667
# 12053                        13.333333                         0.116667
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durchschnitt pro Provinz

# %%
New_Brunswick_mean['time'] = pd.to_datetime(New_Brunswick_mean['time'])

# Monats-Durchschnitt für alle Variablen
New_Brunswick_mean = (
    New_Brunswick_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

New_Brunswick_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                 -8.201075                -3.587097
# 1   1990-02-01                -11.107143                -6.042857
# 2   1990-03-01                 -4.907527                -0.129032
# 3   1990-04-01                  1.967778                 6.658889
# 4   1990-05-01                  6.974194                11.433333
# ..         ...                       ...                      ...
# 392 2022-09-01                 13.857778                18.475556
# 393 2022-10-01                 10.026882                15.192473
# 394 2022-11-01                  1.386667                 5.028889
# 395 2022-12-01                 -3.341935                 0.140860
# 396 2023-01-01                  1.133333                 2.733333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        79.870968                     67.397849
# 1                        72.107143                     55.154762
# 2                        71.752688                     54.096774
# 3                        76.288889                     58.355556
# 4                        76.064516                     56.075269
# ..                             ...                           ...
# 392                      76.533333                     55.222222
# 393                      75.021505                     55.000000
# 394                      72.866667                     57.322222
# 395                      79.333333                     65.397849
# 396                      98.000000                     90.000000
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  3.804301                 5.774194
# 1                  2.192857                 4.214286
# 2                  1.292473                 2.440860
# 3                  3.412222                 5.855556
# 4                  5.126882                 7.505376
# ..                      ...                      ...
# 392                3.468889                 3.666667
# 393                2.682796                 2.709677
# 394                4.505556                 4.444444
# 395                4.861290                 7.408602
# 396               23.500000                23.333333
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     15.022581                  21.770968
# 1                     14.645238                  21.201190
# 2                     14.306452                  19.825806
# 3                     13.614444                  19.045556
# 4                     14.832258                  20.594624
# ..                          ...                        ...
# 392                   12.066667                  17.335556
# 393                   12.295699                  17.849462
# 394                   14.981111                  22.082222
# 395                   15.501075                  22.804301
# 396                   10.333333                  19.733333
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         227.182796                         0.409462
# 1                         234.904762                         0.575952
# 2                         226.096774                         1.170108
# 3                         166.700000                         1.764222
# 4                         141.118280                         2.313763
# ..                               ...                              ...
# 392                       207.333333                         2.561444
# 393                       215.387097                         1.690215
# 394                       236.144444                         0.990778
# 395                       193.677419                         0.454731
# 396                        13.333333                         0.116667
#
# [397 rows x 11 columns]

# %%
# Jahr und Monat extrahieren
New_Brunswick_mean['Year'] = New_Brunswick_mean['time'].dt.year
New_Brunswick_mean['Month'] = New_Brunswick_mean['time'].dt.month
New_Brunswick_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                 -8.201075                -3.587097
# 1   1990-02-01                -11.107143                -6.042857
# 2   1990-03-01                 -4.907527                -0.129032
# 3   1990-04-01                  1.967778                 6.658889
# 4   1990-05-01                  6.974194                11.433333
# ..         ...                       ...                      ...
# 392 2022-09-01                 13.857778                18.475556
# 393 2022-10-01                 10.026882                15.192473
# 394 2022-11-01                  1.386667                 5.028889
# 395 2022-12-01                 -3.341935                 0.140860
# 396 2023-01-01                  1.133333                 2.733333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        79.870968                     67.397849
# 1                        72.107143                     55.154762
# 2                        71.752688                     54.096774
# 3                        76.288889                     58.355556
# 4                        76.064516                     56.075269
# ..                             ...                           ...
# 392                      76.533333                     55.222222
# 393                      75.021505                     55.000000
# 394                      72.866667                     57.322222
# 395                      79.333333                     65.397849
# 396                      98.000000                     90.000000
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  3.804301                 5.774194
# 1                  2.192857                 4.214286
# 2                  1.292473                 2.440860
# 3                  3.412222                 5.855556
# 4                  5.126882                 7.505376
# ..                      ...                      ...
# 392                3.468889                 3.666667
# 393                2.682796                 2.709677
# 394                4.505556                 4.444444
# 395                4.861290                 7.408602
# 396               23.500000                23.333333
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     15.022581                  21.770968
# 1                     14.645238                  21.201190
# 2                     14.306452                  19.825806
# 3                     13.614444                  19.045556
# 4                     14.832258                  20.594624
# ..                          ...                        ...
# 392                   12.066667                  17.335556
# 393                   12.295699                  17.849462
# 394                   14.981111                  22.082222
# 395                   15.501075                  22.804301
# 396                   10.333333                  19.733333
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         227.182796                         0.409462  1990
# 1                         234.904762                         0.575952  1990
# 2                         226.096774                         1.170108  1990
# 3                         166.700000                         1.764222  1990
# 4                         141.118280                         2.313763  1990
# ..                               ...                              ...   ...
# 392                       207.333333                         2.561444  2022
# 393                       215.387097                         1.690215  2022
# 394                       236.144444                         0.990778  2022
# 395                       193.677419                         0.454731  2022
# 396                        13.333333                         0.116667  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os

#Datei speichern
output_path = "../data/cleaned_New_Brunswick_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

New_Brunswick_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## Nova Scotia

# %%
#Yarmouth County Forest (größte Feuerregion NS)
#→ 43.90, -65.95

pfad = "../data/import weather data/import data/Nova Scotia/open-meteo-46.99N65.02W25m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
New_Brunswick_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

New_Brunswick_3

# %%
#Guysborough County Forests
#→ 45.19, -61.60

# %%
#Keji Nationalpark
#→ 44.43, -65.23

# %%
for df in [New_Brunswick_1, New_Brunswick_2, New_Brunswick_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [New_Brunswick_1, New_Brunswick_2, New_Brunswick_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
New_Brunswick_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

New_Brunswick_mean

# %%
New_Brunswick_mean['time'] = pd.to_datetime(New_Brunswick_mean['time'])

# Monats-Durchschnitt für alle Variablen
New_Brunswick_mean = (
    New_Brunswick_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

New_Brunswick_mean

# %%
# Jahr und Monat extrahieren
New_Brunswick_mean['Year'] = New_Brunswick_mean['time'].dt.year
New_Brunswick_mean['Month'] = New_Brunswick_mean['time'].dt.month
New_Brunswick_mean

# %%
import os

#Datei speichern
output_path = "../data/cleaned_New_Brunswick_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

New_Brunswick_mean.to_csv(output_path, index=False)

# %% [markdown]
# ##  Newfoundland and Labrador

# %%
#Labrador – Churchill Falls borealer Wald
#→ 53.55, -64.03

pfad = "../data/import weather data/import data/ Newfoundland and Labrador/open-meteo-53.53N64.02W444m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Newfoundland_and_Labrador_1 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Newfoundland_and_Labrador_1
# Out:
#         latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      53.532513  -64.01532  1990-01-01                     -15.4
# 1      53.532513  -64.01532  1990-01-02                     -19.6
# 2      53.532513  -64.01532  1990-01-03                     -23.5
# 3      53.532513  -64.01532  1990-01-04                     -21.6
# 4      53.532513  -64.01532  1990-01-05                     -20.4
# ...          ...        ...         ...                       ...
# 12049  53.532513  -64.01532  2022-12-28                     -19.6
# 12050  53.532513  -64.01532  2022-12-29                     -17.9
# 12051  53.532513  -64.01532  2022-12-30                     -15.2
# 12052  53.532513  -64.01532  2022-12-31                      -2.3
# 12053  53.532513  -64.01532  2023-01-01                      -9.1
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                        -10.3                             85
# 1                        -13.4                             74
# 2                        -22.8                             73
# 3                        -15.1                             77
# 4                        -14.3                             73
# ...                        ...                            ...
# 12049                    -18.6                             72
# 12050                    -15.1                             78
# 12051                     -8.3                             80
# 12052                      1.1                             87
# 12053                     -4.4                             80
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         8.8                              157
# 1                         1.4                              292
# 2                         0.0                              288
# 3                         0.9                              223
# 4                         1.1                              278
# ...                       ...                              ...
# 12049                     0.0                              265
# 12050                     0.0                              273
# 12051                     2.1                              134
# 12052                     9.1                              256
# 12053                     0.1                              302
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.12                     19.0
# 1                                 0.22                      6.0
# 2                                 0.16                      0.0
# 3                                 0.13                      5.0
# 4                                 0.18                      5.0
# ...                                ...                      ...
# 12049                             0.21                      0.0
# 12050                             0.16                      0.0
# 12051                             0.13                     11.0
# 12052                             0.25                      8.0
# 12053                             0.20                      1.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           22.5                        11.9
# 1                           40.4                        35.2
# 2                           28.7                        24.6
# 3                           22.2                        16.4
# 4                           28.6                        23.9
# ...                          ...                         ...
# 12049                       21.2                        19.9
# 12050                       18.8                        14.8
# 12051                       10.8                         7.3
# 12052                       24.6                        18.6
# 12053                       18.9                        12.2
#
#        relative_humidity_2m_min (%)
# 0                                77
# 1                                72
# 2                                70
# 3                                72
# 4                                66
# ...                             ...
# 12049                            68
# 12050                            76
# 12051                            73
# 12052                            81
# 12053                            74
#
# [12054 rows x 13 columns]

# %%
#Labrador City Forest Zone
#→ 52.95, -66.92


pfad = "../data/import weather data/import data/ Newfoundland and Labrador/open-meteo-52.97N66.95W553m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Newfoundland_and_Labrador_2 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Newfoundland_and_Labrador_2
# Out:
#        latitude  longitude        time  temperature_2m_mean (°C)  \
# 0      52.97012  -66.94916  1990-01-01                     -12.2
# 1      52.97012  -66.94916  1990-01-02                     -25.0
# 2      52.97012  -66.94916  1990-01-03                     -24.2
# 3      52.97012  -66.94916  1990-01-04                     -18.5
# 4      52.97012  -66.94916  1990-01-05                     -22.1
# ...         ...        ...         ...                       ...
# 12049  52.97012  -66.94916  2022-12-28                     -21.2
# 12050  52.97012  -66.94916  2022-12-29                     -19.7
# 12051  52.97012  -66.94916  2022-12-30                     -11.4
# 12052  52.97012  -66.94916  2022-12-31                      -1.3
# 12053  52.97012  -66.94916  2023-01-01                      -9.2
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                        -10.5                             82
# 1                        -18.4                             73
# 2                        -22.0                             76
# 3                         -8.9                             79
# 4                         -8.9                             73
# ...                        ...                            ...
# 12049                    -20.3                             74
# 12050                    -17.1                             79
# 12051                     -5.2                             84
# 12052                      1.2                             90
# 12053                     -3.8                             82
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         8.0                              237
# 1                         0.0                              292
# 2                         0.0                              289
# 3                         1.3                              210
# 4                         0.6                              285
# ...                       ...                              ...
# 12049                     0.0                              266
# 12050                     0.0                              282
# 12051                     4.8                              174
# 12052                     4.2                              259
# 12053                     0.0                              324
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.20                     20.0
# 1                                 0.17                      0.0
# 2                                 0.14                      0.0
# 3                                 0.19                      7.0
# 4                                 0.18                      2.0
# ...                                ...                      ...
# 12049                             0.18                      0.0
# 12050                             0.16                      0.0
# 12051                             0.16                     15.0
# 12052                             0.24                     16.0
# 12053                             0.18                      0.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           37.8                        18.8
# 1                           43.5                        35.9
# 2                           31.2                        23.2
# 3                           27.3                        19.9
# 4                           28.5                        26.5
# ...                          ...                         ...
# 12049                       22.0                        20.0
# 12050                       21.2                        15.0
# 12051                       22.5                        13.3
# 12052                       29.0                        22.2
# 12053                       18.2                         9.4
#
#        relative_humidity_2m_min (%)
# 0                                71
# 1                                71
# 2                                71
# 3                                72
# 4                                66
# ...                             ...
# 12049                            72
# 12050                            76
# 12051                            80
# 12052                            83
# 12053                            80
#
# [12054 rows x 13 columns]

# %%
#Newfoundland – Terra Nova National Park
#→ 48.55, -53.97


pfad = "../data/import weather data/import data/ Newfoundland and Labrador/open-meteo-48.54N53.94W48m.csv"

# -------------------------------------------------------
# 1) Koordinaten aus Zeile 2 (Index 1) einlesen
# -------------------------------------------------------
coords = pd.read_csv(pfad, nrows=2, header=None)
lat = coords.iloc[1, 0]
lon = coords.iloc[1, 1]

df = pd.read_csv(
    pfad,
    skiprows=3,   # Metadaten überspringen
    comment="#",  # ignoriert eventuelle Kommentarzeilen
)

df["latitude"] = lat
df["longitude"] = lon

# Falls du die Spalten vorne haben willst:
Newfoundland_and_Labrador_3 = df[["latitude", "longitude"] + [col for col in df.columns if col not in ["latitude", "longitude"]]]

Newfoundland_and_Labrador_3
# Out:
#         latitude   longitude        time  temperature_2m_mean (°C)  \
# 0      48.541298  -53.939392  1990-01-01                      -3.9
# 1      48.541298  -53.939392  1990-01-02                      -1.4
# 2      48.541298  -53.939392  1990-01-03                      -6.9
# 3      48.541298  -53.939392  1990-01-04                     -10.0
# 4      48.541298  -53.939392  1990-01-05                       0.5
# ...          ...         ...         ...                       ...
# 12049  48.541298  -53.939392  2022-12-28                      -2.8
# 12050  48.541298  -53.939392  2022-12-29                      -6.3
# 12051  48.541298  -53.939392  2022-12-30                      -5.3
# 12052  48.541298  -53.939392  2022-12-31                       0.9
# 12053  48.541298  -53.939392  2023-01-01                       2.7
#
#        temperature_2m_max (°C)  relative_humidity_2m_mean (%)  \
# 0                          6.9                             88
# 1                          7.1                             74
# 2                         -4.5                             68
# 3                         -6.9                             73
# 4                          4.4                             81
# ...                        ...                            ...
# 12049                      1.9                             70
# 12050                     -5.5                             62
# 12051                     -1.7                             69
# 12052                      4.7                             91
# 12053                      4.2                             98
#
#        precipitation_sum (mm)  wind_direction_10m_dominant (°)  \
# 0                         4.8                              191
# 1                         4.1                              244
# 2                         0.0                              263
# 3                         0.0                              268
# 4                         0.6                              224
# ...                       ...                              ...
# 12049                     2.7                              263
# 12050                     0.0                              283
# 12051                     0.0                              276
# 12052                     2.5                              221
# 12053                    14.9                              255
#
#        et0_fao_evapotranspiration (mm)  precipitation_hours (h)  \
# 0                                 0.20                     12.0
# 1                                 0.68                      8.0
# 2                                 0.74                      0.0
# 3                                 0.45                      0.0
# 4                                 0.69                      4.0
# ...                                ...                      ...
# 12049                             0.61                      6.0
# 12050                             0.71                      0.0
# 12051                             0.54                      0.0
# 12052                             0.23                     10.0
# 12053                             0.15                     14.0
#
#        wind_speed_10m_max (km/h)  wind_speed_10m_mean (km/h)  \
# 0                           34.8                        18.3
# 1                           34.9                        29.5
# 2                           33.0                        25.4
# 3                           22.2                        15.2
# 4                           26.8                        22.2
# ...                          ...                         ...
# 12049                       25.1                        15.1
# 12050                       26.4                        18.7
# 12051                       15.9                        10.4
# 12052                       25.6                        18.9
# 12053                       19.7                        11.6
#
#        relative_humidity_2m_min (%)
# 0                                81
# 1                                57
# 2                                60
# 3                                58
# 4                                73
# ...                             ...
# 12049                            49
# 12050                            50
# 12051                            45
# 12052                            77
# 12053                            96
#
# [12054 rows x 13 columns]

# %% [markdown]
# ### Durchschnitt pro Provinz

# %%
for df in [Newfoundland_and_Labrador_1, Newfoundland_and_Labrador_2, Newfoundland_and_Labrador_3]:
    df['time'] = pd.to_datetime(df['time'])

#  drei DataFrames zusammenführen
bc_all = pd.concat(
    [Newfoundland_and_Labrador_1, Newfoundland_and_Labrador_2, Newfoundland_and_Labrador_3],
    ignore_index=True
)

# Wetterspalten definieren
weather_columns = [
    'temperature_2m_mean (°C)',
    'temperature_2m_max (°C)',
    'relative_humidity_2m_mean (%)',
    'relative_humidity_2m_min (%)',
    'precipitation_sum (mm)',
    'precipitation_hours (h)',
    'wind_speed_10m_mean (km/h)',
    'wind_speed_10m_max (km/h)',
    'wind_direction_10m_dominant (°)',
    'et0_fao_evapotranspiration (mm)'
]

# Tagesdurchschnitt über alle 3 Koordinatenpunkte berechnen
Newfoundland_and_Labrador_mean = (
    bc_all
    .groupby('time')[weather_columns]
    .mean()
    .reset_index()
)

Newfoundland_and_Labrador_mean
# Out:
#             time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0     1990-01-01                -10.500000                -4.633333
# 1     1990-01-02                -15.333333                -8.233333
# 2     1990-01-03                -18.200000               -16.433333
# 3     1990-01-04                -16.700000               -10.300000
# 4     1990-01-05                -14.000000                -6.266667
# ...          ...                       ...                      ...
# 12049 2022-12-28                -14.533333               -12.333333
# 12050 2022-12-29                -14.633333               -12.566667
# 12051 2022-12-30                -10.633333                -5.066667
# 12052 2022-12-31                 -0.900000                 2.333333
# 12053 2023-01-01                 -5.200000                -1.333333
#
#        relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                          85.000000                     76.333333
# 1                          73.666667                     66.666667
# 2                          72.333333                     67.000000
# 3                          76.333333                     67.333333
# 4                          75.666667                     68.333333
# ...                              ...                           ...
# 12049                      72.000000                     63.000000
# 12050                      73.000000                     67.333333
# 12051                      77.666667                     66.000000
# 12052                      89.333333                     80.333333
# 12053                      86.666667                     83.333333
#
#        precipitation_sum (mm)  precipitation_hours (h)  \
# 0                    7.200000                17.000000
# 1                    1.833333                 4.666667
# 2                    0.000000                 0.000000
# 3                    0.733333                 4.000000
# 4                    0.766667                 3.666667
# ...                       ...                      ...
# 12049                0.900000                 2.000000
# 12050                0.000000                 0.000000
# 12051                2.300000                 8.666667
# 12052                5.266667                11.333333
# 12053                5.000000                 5.000000
#
#        wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                       16.333333                  31.700000
# 1                       33.533333                  39.600000
# 2                       24.400000                  30.966667
# 3                       17.166667                  23.900000
# 4                       24.200000                  27.966667
# ...                           ...                        ...
# 12049                   18.333333                  22.766667
# 12050                   16.166667                  22.133333
# 12051                   10.333333                  16.400000
# 12052                   19.900000                  26.400000
# 12053                   11.066667                  18.933333
#
#        wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                           195.000000                         0.173333
# 1                           276.000000                         0.356667
# 2                           280.000000                         0.346667
# 3                           233.666667                         0.256667
# 4                           262.333333                         0.350000
# ...                                ...                              ...
# 12049                       264.666667                         0.333333
# 12050                       279.333333                         0.343333
# 12051                       194.666667                         0.276667
# 12052                       245.333333                         0.240000
# 12053                       293.666667                         0.176667
#
# [12054 rows x 11 columns]

# %% [markdown]
# ### Durchschnitt pro Monat

# %%
Newfoundland_and_Labrador_mean['time'] = pd.to_datetime(Newfoundland_and_Labrador_mean['time'])

# Monats-Durchschnitt für alle Variablen
Newfoundland_and_Labrador_mean = (
    Newfoundland_and_Labrador_mean
    .set_index('time')
    .resample('MS')
    .mean()
    .reset_index()
)

Newfoundland_and_Labrador_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -17.311828               -13.080645
# 1   1990-02-01                -21.377381               -16.767857
# 2   1990-03-01                -12.329032                -7.993548
# 3   1990-04-01                 -3.592222                 0.233333
# 4   1990-05-01                  1.768817                 5.438710
# ..         ...                       ...                      ...
# 392 2022-09-01                 11.550000                14.902222
# 393 2022-10-01                  7.200000                10.531183
# 394 2022-11-01                 -3.124444                -0.148889
# 395 2022-12-01                 -6.889247                -3.804301
# 396 2023-01-01                 -5.200000                -1.333333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        76.569892                     69.473118
# 1                        71.452381                     62.428571
# 2                        74.258065                     62.913978
# 3                        79.622222                     66.577778
# 4                        78.698925                     63.365591
# ..                             ...                           ...
# 392                      81.588889                     64.466667
# 393                      79.989247                     64.075269
# 394                      79.311111                     68.666667
# 395                      83.645161                     76.311828
# 396                      86.666667                     83.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.537634                 3.580645
# 1                  1.534524                 3.488095
# 2                  1.441935                 2.612903
# 3                  2.713333                 5.822222
# 4                  2.647312                 4.440860
# ..                      ...                      ...
# 392                5.596667                 7.200000
# 393                2.281720                 4.935484
# 394                3.460000                 7.866667
# 395                3.149462                 6.236559
# 396                5.000000                 5.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     16.498925                  23.152688
# 1                     17.604762                  24.186905
# 2                     16.897849                  22.473118
# 3                     16.294444                  22.815556
# 4                     15.141935                  20.783871
# ..                          ...                        ...
# 392                   15.535556                  21.912222
# 393                   16.698925                  23.100000
# 394                   16.605556                  24.500000
# 395                   16.826882                  23.213978
# 396                   11.066667                  18.933333
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)
# 0                         223.000000                         0.243226
# 1                         245.035714                         0.297857
# 2                         257.720430                         0.704409
# 3                         191.033333                         1.249889
# 4                         167.774194                         1.862688
# ..                               ...                              ...
# 392                       212.022222                         1.657000
# 393                       215.731183                         1.153441
# 394                       224.722222                         0.515222
# 395                       175.440860                         0.267634
# 396                       293.666667                         0.176667
#
# [397 rows x 11 columns]

# %%
# Jahr und Monat extrahieren
Newfoundland_and_Labrador_mean['Year'] = Newfoundland_and_Labrador_mean['time'].dt.year
Newfoundland_and_Labrador_mean['Month'] = Newfoundland_and_Labrador_mean['time'].dt.month
Newfoundland_and_Labrador_mean
# Out:
#           time  temperature_2m_mean (°C)  temperature_2m_max (°C)  \
# 0   1990-01-01                -17.311828               -13.080645
# 1   1990-02-01                -21.377381               -16.767857
# 2   1990-03-01                -12.329032                -7.993548
# 3   1990-04-01                 -3.592222                 0.233333
# 4   1990-05-01                  1.768817                 5.438710
# ..         ...                       ...                      ...
# 392 2022-09-01                 11.550000                14.902222
# 393 2022-10-01                  7.200000                10.531183
# 394 2022-11-01                 -3.124444                -0.148889
# 395 2022-12-01                 -6.889247                -3.804301
# 396 2023-01-01                 -5.200000                -1.333333
#
#      relative_humidity_2m_mean (%)  relative_humidity_2m_min (%)  \
# 0                        76.569892                     69.473118
# 1                        71.452381                     62.428571
# 2                        74.258065                     62.913978
# 3                        79.622222                     66.577778
# 4                        78.698925                     63.365591
# ..                             ...                           ...
# 392                      81.588889                     64.466667
# 393                      79.989247                     64.075269
# 394                      79.311111                     68.666667
# 395                      83.645161                     76.311828
# 396                      86.666667                     83.333333
#
#      precipitation_sum (mm)  precipitation_hours (h)  \
# 0                  1.537634                 3.580645
# 1                  1.534524                 3.488095
# 2                  1.441935                 2.612903
# 3                  2.713333                 5.822222
# 4                  2.647312                 4.440860
# ..                      ...                      ...
# 392                5.596667                 7.200000
# 393                2.281720                 4.935484
# 394                3.460000                 7.866667
# 395                3.149462                 6.236559
# 396                5.000000                 5.000000
#
#      wind_speed_10m_mean (km/h)  wind_speed_10m_max (km/h)  \
# 0                     16.498925                  23.152688
# 1                     17.604762                  24.186905
# 2                     16.897849                  22.473118
# 3                     16.294444                  22.815556
# 4                     15.141935                  20.783871
# ..                          ...                        ...
# 392                   15.535556                  21.912222
# 393                   16.698925                  23.100000
# 394                   16.605556                  24.500000
# 395                   16.826882                  23.213978
# 396                   11.066667                  18.933333
#
#      wind_direction_10m_dominant (°)  et0_fao_evapotranspiration (mm)  Year  \
# 0                         223.000000                         0.243226  1990
# 1                         245.035714                         0.297857  1990
# 2                         257.720430                         0.704409  1990
# 3                         191.033333                         1.249889  1990
# 4                         167.774194                         1.862688  1990
# ..                               ...                              ...   ...
# 392                       212.022222                         1.657000  2022
# 393                       215.731183                         1.153441  2022
# 394                       224.722222                         0.515222  2022
# 395                       175.440860                         0.267634  2022
# 396                       293.666667                         0.176667  2023
#
#      Month
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 392      9
# 393     10
# 394     11
# 395     12
# 396      1
#
# [397 rows x 13 columns]

# %%
import os

#Datei speichern
output_path = "../data/cleaned_Newfoundland_and_Labrador_monthly_mean.csv"

# Sicherstellen, dass das Verzeichnis existiert
os.makedirs(os.path.dirname(output_path), exist_ok=True)

Newfoundland_and_Labrador_mean.to_csv(output_path, index=False)

# %% [markdown]
# ## Prince Edward Island
